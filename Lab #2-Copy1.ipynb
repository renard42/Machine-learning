# %%
import pandas as pd
import numpy as np

# %%
neg = pd.read_csv('negative.csv', sep=';', header=None)

# %%
pos = pd.read_csv('positive.csv', sep=';', header=None)
pos.columns = ['id', 'date', 'name', 'text', 'class', 'rep', 'retw', 'fav', 'count', 'foll', 'friend', 'list']
neg.columns = ['id', 'date', 'name', 'text', 'class', 'rep', 'retw', 'fav', 'count', 'foll', 'friend', 'list']

# %%
pos_choose = round(10000*0.7)#len(pos)
neg_choose = round(10000*0.3)#round(pos_choose*0.3/0.7)
#neg_choose = round(pos_choose*0.3/0.7)

pos_choose, neg_choose
# Out:
# (7000, 3000)

# %%
pos = pos.sample(frac=1).reset_index(drop=True)
neg = neg.sample(frac=1).reset_index(drop=True)

# %%
pos_new = pos[:pos_choose]
neg_new = neg[:neg_choose]

model_pos = pos[pos_choose:]
model_neg = neg[neg_choose:]

# %%
model_w2v = model_pos.append(model_neg)
model_w2v.to_csv('model_learn.csv', sep=';', encoding='utf-8')

# %%
tweets = pos_new.append(neg_new)
tweets = tweets.sample(frac=1).reset_index(drop=True)

tweets.to_csv('tweets.csv', sep=';', encoding='utf-8')

# %%
tweets = pd.read_csv('tweets.csv', sep=';').drop('Unnamed: 0', axis = 1)

print("Null values: {0}".format(tweets.isnull().values.any()))
print("Count of NaN values: {0}".format(np.sum(tweets.isnull().values)))

    
print('Object types: ', [c for c in tweets.columns if tweets[c].dtype.name == 'object'])
# Out:
# Null values: False
# Count of NaN values: 0
# Object types:  ['name', 'text']

# %%
try:
    from nltk.corpus import stopwords
except:
    import nltk
    nltk.download('stopwords')
    from nltk.corpus import stopwords

stop_words = stopwords.words('russian')
removal = ['хорошо', 'лучше', 'нельзя', 'больше', 'никогда', 'ничего']

for i in removal:
    stop_words.remove(i)
stop_words.append('rt')

# %%
tweets
# Out:
#                       id        date             name  \
# 0     415181576839102464  1387821976   marina_heyless
# 1     416952256219873280  1388244139  arai_zhambulova
# 2     410790557762723840  1386775075   MarinaP_LOVE1D
# 3     410824957753438208  1386783277       KorzhZlata
# 4     424109402048569346  1389950535    sanyanizamova
# 5     411216797518790657  1386876699        amovuparu
# 6     410813586010034176  1386780566         averaage
# 7     415033037131616256  1387786561         TessCold
# 8     409608602446753792  1386493275     KsushaNandos
# 9     410462706399854592  1386696909  abrosimovaviole
# 10    420647395207024641  1389125128  SashkaPetrashko
# 11    411364701172695040  1386911962       mc_focus21
# 12    412624767733481472  1387212385      Alpachino57
# 13    409319450530177024  1386424336          mootsoo
# 14    425007353118085120  1390164623  Margo_Shamugiya
# 15    409938720478199808  1386571981     mijehevababu
# 16    411435612563308544  1386928868  irakravchenko46
# 17    410091288705241088  1386608357       alina_2505
# 18    423697121452097536  1389852240          Svetlyi
# 19    409968450241843200  1386579070       A_Avetisov
# 20    410009428306690048  1386588839  violetta_blonde
# 21    409895683467268097  1386561721   jaxuvufemibozo
# 22    417230789332709376  1388310546          Modenov
# 23    412242548653309952  1387121257      olivermudak
# 24    418867218274062336  1388700701      Crazy_Vikos
# 25    411199365085405184  1386872543       Polly_Brez
# 0       0    292    134      36     0
# 1       0      9     41     430     0
# 2       0  13814   1571    1431     4
# 3       0   1473     27      24     0
# 4       0    115     17      13     0
# 5       0    281    252     270     0
# 6       0  20256    115      47     0
# 7       0   1568   1177     845     0
# 8       0   9059   2175    1813     4
# 9       0    106      8      22     0
# 10      0    510     33      54     1
# 11      0   2891     39      38     0
# 12      0    124     24      19     0
# 13      0  34039   2228     648    18
# 14      0    851     26      22     1
# 15      0    546    205     187     0
# 16      0    167     20      20     0
# 17      0    478     11       8     0
# 18      0  18532    407     173    12
# 19      0   1953    319     293     9
# 20      0   1647    107     100     0
# 21      0    207     59      54     0
# 22      0  25666   1074     868    41
# 23      0  18208    201     147     0
# 24      0  61633   3304     576    45
# 25      0  13790    107     100     2
# 26      0  22354    424     142    13
# 27      0    593   1113     852     1
# 28      0   1010     60     115     1
# 29      0   1477     30      30     0
# ...   ...    ...    ...     ...   ...
# 9970    0     85     78      83     0
# 9971    0     93     13       6     0
# 9972    0     50     10      20     0
# 9973    0    625     31      58     0
# 9974    0    950     30      23     0
# 9975    0   2988     45      43     0
# 9976    0  45600    551     276    17
# 9977    0  19294    139      54     5
# 9978    0    330    101     109     0
# 9979    0  51575   3353    1765    32
# 9980    0    295    154     153     0
# 9981    0  25493    535     388     9
# 9982    0    655    349     337     0
# 9983    0    168     24      31     0
# 9984    0   2813    239     173     1
# 9985    0   5022    116      66     3
# 9986    0    543    188     175     0
# 9987    0    164    328     320     0
# 9988    0   1939     33      29     0
# 9989    0   9050     84      70     1
# 9990    0   3043    148     101     2
# 9991    0   9111  18345   17010    16
# 9992    0    933     17      24     0
# 9993    0  13510    187      91    11
# 9994    0  19724    797     246   100
# 9995    0    250     78     162     0
# 9996    0     16      7      54     0
# 9997    0    682    255     319     2
# 9998    0    150     14      18     0
# 9999    0   6612    641     216    21
#
# [10000 rows x 12 columns]

# %%
from re import compile, findall
from nltk import tokenize
from pymystem3 import Mystem

names = compile('@\S+')
exclude = compile('http:\S+')
tag = compile('#\S+')
emoji_good = compile('[:;]?-?[)d]+')
emoji_bad = compile('[:;]?-?[(\|]+')

m = Mystem()

def text_process(list_tweets):
    new_tweets = []
    for num, elem in enumerate(list_tweets['text']):
        
        elem = elem.lower()
        #print(elem)
        names_list = names.findall(elem)
        links = exclude.findall(elem)
        tags = tag.findall(elem)
        e_good = emoji_good.findall(elem)
        e_bad = emoji_bad.findall(elem)
        dots = findall('\.\.\.', elem)
        
        #print(num, len(names_list))
        list_tweets.at[num, 'people'] = len(names_list)
        list_tweets.at[num, 'tags'] = len(tags)
        list_tweets.at[num, 'emoji_good'] = len(e_good)
        list_tweets.at[num, 'emoji_bad'] = len(e_bad)
        list_tweets.at[num, 'three_dots'] = len(dots)

        tweet = findall('\S+', elem)
        tweet = ' '.join([i for i in tweet if i not in names_list and i not in links and i not in tags])    

        tws = [k for k in tokenize.word_tokenize(tweet) if k not in stop_words and k.isalpha() == True and k not in e_good]    
        new_tweets.append(tws)
        if num%1000 == 0:
            print('done #' + str(num))
    print('DONE ALL')  
    return new_tweets

# %%
# 111920  416869661645737984  1388224447           Okodim
# 111921  415034922186063872  1387787011       KSENIAVASI
# 111922  410491483780050944  1386703770      DoctorZefir
#
#                                                      text  class  rep  retw  \
# 7000    @Ookami_Horo ответ ниже %) страдания по поводу...      1    0     0
# 7001    RT @cuqiqeqivog: Сегодня я вне зоны доступа, п...      1    0     1
# 7002    @DLovatoKJNJonas Ник просил просил передать ДЖ...      1    0     0
# 7003    @Frolova1551 я болею!:) это очень интересно? Х...      1    0     0
# 7004    @Vikusechka_0406 хорошо) ты как? #mtvstars One...      1    0     0
# 7005    @rapsatfrompvl @Nota_bene_easy для меня что ск...      1    0     0
# 7006    @ramil_v8 @skitles_ Даааа) только начала смотр...      1    0     0
# 7007    сколько человек на тебя подписано??новая функц...      1    0     0
# 7008    RT @MinZurka1997: Фуф)Слава Богу жив, здоров!\...      1    0     1
# 7009    @beterthen конечно передал ,сразу же как разош...      1    0     0
# 7010    Нехрен жалеть руки и гитару. Поставил металлич...      1    0     0
# 7011    - Каковы Ваши требования к будущей жене? - А) ...      1    0     0
# 7012    RT @dinkar705: "@_K_M_V_: Красавец!) http://t....      1    0     2
# 7013    @kuguarrr ой а чтоооо там, я бы вообще ее всю ...      1    0     0
# 7014    охаё, твич. проснулась с лёгкой ненавистью к с...      1    0     0
# 7015    "У нее даже нет времени скучать по сестре"\nах...      1    0     0
# 7016    @Daniella_lia ахаха только заметила, там не со...      1    0     0
# 7017    RT @Creative_Link: Дождались! Официальный трей...      1    0   933
# 7018    тебе хорошо с ним в сексе, потому что нет срав...      1    0     0
# 7019    Ладно :D Раз не удалось сегодня перенести сайт...      1    0     0
# 7020    сегодня городская кр по геометрии. решила, что...      1    0     0
# 7021    RT @Ninel_vasil: Я умею скучать по глазам и го...      1    0     1
# 7022    а мы с ним серьёзные бывшие) аах) можно и вспо...      1    0     0
# 7023    На днях батя привёз элитной картохи ) целых 2 ...      1    0     1
# 7024    О,да! ходила с сестрой на каток . давно я так ...      1    0     0
# 7025    В тебе нет рамантики, ты не идеал, но я тебя л...      1    0     0
# 7026    Всех с Днем конституции РФ !:)\nзаконы хоть ко...      1    0     0
# 7027    @Azazel_buka я смотрела два сезона! потом у мн...      1    0     0
# 7028    @boss8875 я с @zenit_spb путешествовал и стара...      1    0     0
# 7029    Ты меня не знаешь. мне просто интересно. — нет...      1    0     0
# ...                                                   ...    ...  ...   ...
# 111893  Добралась до фитнеса, думала отдохну. Все вдру...     -1    0     0
# 111894  @Gansgidra какоее?( я уже какой день придумать...     -1    0     0
# 111895        RT @NikySHARP: Хочу быть Михал Борисычем:-(     -1    0     1
# 111896  @catvanda @morozov_si  я тоже не понимаю почем...     -1    0     0
# 111897  @Nevedom2008 привет. если есть лишний код на г...     -1    0     0
# 111898  не могу продумать свой тур в Китай ((( Можно л...     -1    0     0
# 111899  RT @NARKOTAA: @brawn_alex я знала, но случайно...     -1    0     1
# 111900  Должнн был Руслан приехать, а из-за моей лени,...     -1    0     0
# 111901      Вот млин, батарейка на любимом swatch сели(((     -1    0     0
# done #210000
# done #211000
# done #212000
# done #213000
# done #214000
# done #215000
# done #216000
# DONE ALL

# %%
model_train
# Out:
# [['ответ', 'ниже', 'страдания', 'поводу'],
#  ['сегодня', 'вне', 'зоны', 'доступа', 'просто', 'сеть', 'берёт'],
#  ['ник', 'просил', 'просил', 'передать', 'джо', 'дебил'],
#  ['болею',
#   'это',
#   'очень',
#   'интересно',
#   'хотя',
#   'понедельник',
#   'концерт',
#   'очень',
#   'весело'],
#  ['хорошо', 'one', 'direction'],
#  ['скриптонит',
#   'яникс',
#   'хуйня',
#   'хотя',
#   'английском',
#   'скриптонита',
#   'слушать'],
#  ['даааа', 'начала', 'смотреть', 'нравится'],
#  ['сколько',
#   'человек',
#   'подписано',
#   'новая',
#   'функция',
#   'посмотри',
#   'профиле'],
#  ['фуф', 'слава', 'богу', 'жив', 'здоров', 'очень', 'напугал'],
#  ['передал', 'сразу', 'разошлись', 'тобой'],
#  ['нехрен', 'жалеть', 'руки', 'гитару', 'поставил', 'металлические'],
#  ['каковы', 'ваши', 'требования', 'будущей', 'жене', 'б', 'amp'],
#  ['красавец'],
#  ['ой', 'чтоооо', 'вообще', 'пересмотрела'],
#  ['охаё',
#   'твич',
#   'проснулась',
#   'лёгкой',
#   'ненавистью',
#   'соседям',
#   'решимостью',
#   'сделать',
#   'всё',
#   'планировалось',
#   'неделю',
#   'х'],
#  ['времени',
#   'скучать',
#   'сестре',
#   'ахаха',
#   'правда',
#   'соскучилась',
#   'знаю',
#   'приедет',
#   'скотина',
#   'd'],
#  ['ахаха', 'заметила', 'плохо'],
#  ['дождались',
#   'официальный',
#   'трейлер',
#   'иван',
#   'царевич',
#   'серый',
#   'волк',
#   'смотреть',
#   'всем',
#   'толи'],
#  ['тебе', 'хорошо', 'сексе', 'сравнения'],
#  ['ладно',
#   'd',
#   'удалось',
#   'сегодня',
#   'перенести',
#   'сайт',
#   'сделаю',
#   'новый',
#   'дизайн',
#   'd'],
#  ['сегодня',
#   'городская',
#   'кр',
#   'геометрии',
#   'решила',
#   'сегодня',
#   'ночью',
#   'буду',
#   'спать',
#   'буду',
#   'посплю',
#   'пойду',
#   'сделаю'],
#  ['умею',
#   'скучать',
#   'глазам',
#   'голосу',
#   'отдельно',
#   'непосредственного',
#   'обладателя'],
#  ['серьёзные', 'бывшие', 'аах', 'вспомнить', 'прошлое'],
#  ['днях',
#   'батя',
#   'привёз',
#   'элитной',
#   'картохи',
#   'целых',
#   'ведра',
#   'красивом',
#   'зелёном',
#   'мешке'],
#  ['ходила', 'сестрой', 'каток', 'давно', 'веселилась', 'х'],
#  ['тебе', 'рамантики', 'идеал', 'люблю', 'просто'],
#  ['днем', 'конституции', 'рф', 'законы', 'косвенно', 'знать'],
#  ['смотрела', 'сезона', 'мня', 'проблемы', 'инетом', 'лень', 'd'],
#  ['путешествовал', 'стараюсь', 'путешествовать'],
#  ['знаешь',
#   'просто',
#   'интересно',
#   'чувак',
#   'прости',
#   'это',
#   'информация',
#   'избранных'],
#  ['ага', 'выгонят', 'мою', 'тупость'],
#  ['крутой',
#   'день',
#   'классом',
#   'ооо',
#   'молком',
#   'самая',
#   'лучшая',
#   'фраза',
#   'экскурсовода',
#   'рассказываю',
#   'черта',
#   'слушают',
#   'ахахаха'],
#  ['завтра',
#   'ждет',
#   'тяжелая',
#   'игра',
#   'хотим',
#   'выиграть',
#   'прийдется',
#   'играть',
#   'конца',
#   'выкладываться',
#   'вмдтк'],
#  ['привеееет',
#   'новому',
#   'читателю',
#   'счастьяздоровьявстречискумиром',
#   'держи',
#   'свой',
#   'подарок'],
#  ['чет', 'твитнуть', 'ебанутый', 'понимает'],
#  ['ахах', 'котом', 'лучше'],
#  ['дома',
#   'появился',
#   'сижу',
#   'жду',
#   'сообщение',
#   'любимой',
#   'доехала',
#   'вечер',
#   'день',
#   'рождение',
#   'семы',
#   'потрясающий'],
#  ['жуйкопары', 'праздником', 'отдельно'],
#  ['б', 'взяли', 'интервью', 'ещё', 'неприятнее', 'наверное'],
#  ['юпе', 'понимать'],
#  ['люблю',
#   'зиму',
#   'люди',
#   'носом',
#   'разблокируют',
#   'телефоны',
#   'такие',
#   'оглядываются',
#   'типа',
#   'палева',
#   'вижу'],
#  ['пишет',
#   'учитывая',
#   'времени',
#   'сижу',
#   'телефона',
#   'это',
#   'отвлекает',
#   'пишет',
#   'часто',
#   'интересно',
#   'поэтому'],
#  ['буду',
#   'ходить',
#   'домам',
#   'буду',
#   'снегурочкой',
#   'новый',
#   'год',
#   'точнее',
#   'новым',
#   'годоооом'],
#  ['племяшек', 'глянуть', 'забыл'],
#  ['вода',
#   'утекает',
#   'огонь',
#   'гаснет',
#   'землю',
#   'растаптывают',
#   'воздух',
#   'остается'],
#  ['общалась', 'другом', 'окошке', 'родном', 'языке', 'нем', 'продолжила'],
#  ['хотели',
#   'идти',
#   'убивать',
#   'соседа',
#   'алкаша',
#   'дебоширство',
#   'услышали',
#   'слушает',
#   'kiss',
#   'зауважали'],
#  ['время', 'включили', 'мтв', 'мин', 'каникулы', 'мексике', 'сезон'],
#  ['хаха', 'нужна', 'шучу'],
#  ['ахаха', 'сладких', 'снов'],
#  ['класс', 'вяжу', 'всё', 'кроме', 'носкофф', 'умею'],
#  ['никогда',
#   'сдерживается',
#   'чихает',
#   'ахахахаха',
#   'будем',
#   'сдерживаться',
#   'лол'],
#  ['слушателей', 'сегодняшнего', 'послания', 'путина', 'выдержал'],
#  ['нашел', 'неизвестных', 'песен', 'охуенны', 'прям'],
#  ['adelkhalilova', 'анютка', 'любит', 'поезда', 'осторожнее', 'ирисками'],
#  ['очень', 'рада', 'знакомству', 'послушай', 'очень', 'хорошие', 'песни'],
#  ['сорь', 'братуха', 'привет'],
#  ['февраля', 'отмечают', 'марта', 'марта', 'должно', 'отмечаться', 'февраля'],
#  ['младшая',
#   'сестра',
#   'кушать',
#   'вишневое',
#   'варенье',
#   'выплёвывать',
#   'косточки',
#   'туда',
#   'd'],
#  ['смылсле',
#   'safari',
#   'лучше',
#   'точки',
#   'зрения',
#   'ux',
#   'заставляет',
#   'людей',
#   'страдать',
#   'поступают',
#   'неправильно'],
#  ['прекрасная', 'поездка', 'просто', 'отличные', 'ошущения', 'сказке'],
#  ['единственная',
#   'проблемма',
#   'захватывающих',
#   'сериалах',
#   'слишком',
#   'нервничаю',
#   'остаюсь',
#   'ногтей'],
#  ['щас', 'закончили', 'мамой', 'отдохнуть'],
#  ['привееет', 'хорошо', 'тебе'],
#  ['завтра', 'отпишусь', 'буду', 'компа', 'приду', 'пока', 'лентушка'],
#  ['это', 'читать', 'просто', 'умею', 'подавно'],
#  ['пришла',
#   'бассейна',
#   'пообещала',
#   'жрать',
#   'ага',
#   'сижу',
#   'одну',
#   'харю',
#   'поедаю',
#   'мамин',
#   'пирог',
#   'd'],
#  ['the',
#   'offspring',
#   'kristi',
#   'are',
#   'you',
#   'doing',
#   'okay',
#   'никогда',
#   'перестанет',
#   'нравиться',
#   'никогда',
#   'перестанет',
#   'напоминать',
#   'владика'],
#  ['подумаешь',
#   'сбила',
#   'пару',
#   'кем',
#   'бывает',
#   'зато',
#   'знаю',
#   'полудохлых',
#   'сопартийцев',
#   'давить',
#   'нельзя'],
#  ['вчерашний', 'вечер', 'незабываемый'],
#  ['уравнения',
#   'просто',
#   'уравнения',
#   'обычные',
#   'белорусские',
#   'уравнения',
#   'похоже',
#   'одна',
#   'понимаю'],
#  ['хозмаге', 'приобрести', 'заправке'],
#  ['зайдет', 'охуеет'],
#  ['выводе',
#   'сегодняшнего',
#   'дня',
#   'доктор',
#   'эгоистический',
#   'мафия',
#   'большинстве',
#   'случаев',
#   'отличная',
#   'd'],
#  ['джейми', 'исполняет', 'плачу'],
#  ['баярлалаа', 'бурхад', 'минь', 'эруул', 'саруул', 'урт', 'удаан', 'наслаг'],
#  ['закинула', 'юльку', 'чс', 'ахахахах', 'запарила', 'отвлекать', 'ахахпх'],
#  ['пойдемте', 'шум', 'эмин', 'напоит'],
#  ['удобная',
#   'штука',
#   'мак',
#   'могу',
#   'кухни',
#   'айфона',
#   'управлять',
#   'музыкой',
#   'ноуте',
#   'комнате',
#   'комнате',
#   'пульта'],
#  ['кидаю', 'фотки', 'd', 'смешно', 'столько', 'фоток'],
#  ['маршрутке',
#   'водитель',
#   'угостил',
#   'конфетками',
#   'сказал',
#   'очень',
#   'милая',
#   'девочка',
#   'ахахха',
#   'такое',
#   'бывает'],
#  ['ребенок', 'считаю', 'дни', 'нового', 'года', 'хотя', 'возьмешь', 'ребенок'],
#  ['конец', 'выспалась', 'всем', 'хорошего', 'утра', 'настроения'],
#  ['ляпис', 'время', 'играет', 'последний', 'это', 'песня', 'железный'],
#  ['забыл', 'настоящий', 'коммунист', 'это', 'ребенок'],
#  ['аахаххаха', 'лучше', 'это', 'запоминала'],
#  ['полина',
#   'сказала',
#   'очень',
#   'похудели',
#   'ноги',
#   'шам',
#   'сказала',
#   'сильно',
#   'похудело',
#   'лицо',
#   'это',
#   'хотя',
#   'заметно'],
#  ['пока', 'настроишься', 'сопрут'],
#  ['сбежали', 'дурдома', 'дворе'],
#  ['вернулся',
#   'убитого',
#   'джимми',
#   'сказал',
#   'пшел',
#   'нахер',
#   'дин',
#   'лижу',
#   'зад',
#   'богу',
#   'тебе',
#   'х'],
#  ['php',
#   'нуб',
#   'благодаря',
#   'модулю',
#   'content',
#   'templates',
#   'здравой',
#   'эрудиции',
#   'неплохо',
#   'получается'],
#  ['дааааааааааааа', 'история', 'мучаю', 'гуляем', 'd'],
#  ['одноклассники', 'сказали', 'нi', 'кличко'],
#  ['это', 'нашла', 'твой', 'паблик', 'вк', 'пишешь', 'вдохновляет'],
#  ['котейка', 'ждёт', 'нового', 'года'],
#  ['сегодня',
#   'стал',
#   'свидетелем',
#   'удивительного',
#   'явления',
#   'температура',
#   'воды',
#   'выше',
#   'температуры',
#   'воздуха',
#   'воды',
#   'шел',
#   'пар'],
#  ['евросоюз',
#   'грозит',
#   'санкциями',
#   'украинским',
#   'чиновникам',
#   'дааа',
#   'угрожают'],
#  ['отвык', 'отработы', 'неделю', 'ходил', 'вообще', 'минск', 'срочно'],
#  ['люблю',
#   'зиму',
#   'люди',
#   'носом',
#   'разблокируют',
#   'телефоны',
#   'такие',
#   'оглядываются',
#   'типа',
#   'палева',
#   'вижу'],
#  ['ппфффф',
#   'нах',
#   'водка',
#   'ебоная',
#   'есь',
#   'люди',
#   'олкаши',
#   'лучш',
#   'нопоили',
#   'дашираком'],
#  ['хаха', 'youtube', 'слегка', 'курнул', 'dddd'],
#  ['уверен', 'спасают', 'правда', 'жопу', 'спасают', 'вахахххах'],
#  ['одна',
#   'мысль',
#   'крутится',
#   'такое',
#   'нашей',
#   'истории',
#   'называется',
#   'коммунизм'],
#  ['ураааааа',
#   'серьезно',
#   'чемпионы',
#   'лиги',
#   'квн',
#   'кузбасс',
#   'отдельно',
#   'поздравляю',
#   'диму',
#   'конышева',
#   'ксюшу',
#   'говорится',
#   'любви',
#   'счастья'],
#  ['бл', 'вынесло', 'd', 'джинни', 'уизли', 'книге', 'фильме'],
#  ['ахирел', 'читает', 'сучача'],
#  ['русском', 'сижу', 'скучно', 'лента', 'попереписывайся', 'мной', 'плз'],
#  ['цагийн', 'зөрүүтэй', 'газар', 'үдэш', 'болжийн'],
#  ['meowки', 'мои'],
#  ['квн',
#   'отличный',
#   'кого',
#   'хотел',
#   'увидеть',
#   'увидел',
#   'пришёл',
#   'плохой',
#   'новостью',
#   'температура'],
#  ['оформления', 'документов', 'принесите', 'фотографии', 'диске', 'd'],
#  ['вообще', 'люблю', 'текстуру', 'снимать', 'всякую', 'херню'],
#  ['оо',
#   'писали',
#   'контрольную',
#   'физике',
#   'думаю',
#   'оценка',
#   'надеюсь',
#   'лучшее',
#   'd'],
#  ['доброе', 'утро'],
#  ['хочу', 'передать', 'привет', 'никите', 'напомнить', 'очень', 'классный'],
#  ['пошел',
#   'гулять',
#   'зато',
#   'пиздатая',
#   'верста',
#   'пошла',
#   'отличный',
#   'вечер',
#   'коньяку',
#   'ваще',
#   'збс'],
#  ['кстати',
#   'знают',
#   'вчера',
#   'выстояли',
#   'против',
#   'бойцов',
#   'беркута',
#   'бойцов',
#   'внутренних',
#   'войск',
#   'слава'],
#  ['пашка',
#   'намекает',
#   'нам',
#   'нам',
#   'плохие',
#   'шуточки',
#   'щи',
#   'выносить',
#   'кружок',
#   'записался'],
#  ['концу',
#   'бутылочки',
#   'био',
#   'баланса',
#   'начало',
#   'казаться',
#   'просроченный',
#   'мммм',
#   'клаааассно'],
#  ['ругаешься', 'матом', 'позвоню', 'тебе', 'утра', 'поговорим', 'd'],
#  ['днем', 'рождения', 'благополучия', 'пусть', 'солнце', 'душе', 'головой'],
#  ['тобой',
#   'общается',
#   'самое',
#   'подумай',
#   'ничего',
#   'плохого',
#   'тебе',
#   'отлично',
#   'отнашусь'],
#  ['день', 'варенья', 'паздравляю', 'счастья', 'веры'],
#  ['знаю',
#   'это',
#   'ленте',
#   'нету',
#   'ничего',
#   'ретвитт',
#   'вообще',
#   'понимаю',
#   'популярности',
#   'тви'],
#  ['автобусе',
#   'встречаешься',
#   'взглядом',
#   'хочешь',
#   'выходить',
#   'своей',
#   'остановке'],
#  ['получилась', 'дикая', 'абстракция', 'духе', 'современного', 'искусства'],
#  ['итак',
#   'понравился',
#   'молодцы',
#   'скорей',
#   'увидеть',
#   'это',
#   'пати',
#   'остальными',
#   'ребятами'],
#  ['начал',
#   'потиху',
#   'конвертить',
#   'фотки',
#   'подготовке',
#   'ролика',
#   'эх',
#   'похоже',
#   'всё',
#   'покажем'],
#  ['понятия', 'имею', 'привлекла', 'эта', 'картинка', 'http'],
#  ['ааее', 'неожиданно', 'безумно', 'приятно', 'нуу', 'спасиибоо'],
#  ['обеденный',
#   'перерыв',
#   'последняя',
#   'рабочая',
#   'неделка',
#   'полная',
#   'свобода'],
#  ['кстати', 'сказала', 'скайп', 'подумал', 'первую', 'очередь', 'дождь'],
#  ['шли', 'нахуй', 'прекрасна', 'хах', 'ок', 'спасибо'],
#  ['жизни', 'написала', 'первая', 'никогда', 'точку', 'd'],
#  ['пойду', 'сгоняю', 'душ', 'постараюсь', 'недолго', 'пошлостей', 'd'],
#  ['браво', 'это', 'походу', 'единственный', 'выход'],
#  ['никита', 'рязанском', 'кремле'],
#  ['знаю', 'комплименты', 'напрашиваешься', 'желание', 'отбивает', 'лол'],
#  ['следущей',
#   'недели',
#   'открываю',
#   'бизнес',
#   'шоколадках',
#   'альпен',
#   'гольд',
#   'третья',
#   'недели',
#   'списывание',
#   'шпору'],
#  ['люблю',
#   'зиму',
#   'люди',
#   'носом',
#   'разблокируют',
#   'телефоны',
#   'такие',
#   'оглядываются',
#   'типа',
#   'палева',
#   'вижу'],
#  ['обожаю',
#   'своих',
#   'соседей',
#   'слушают',
#   'полную',
#   'громкость',
#   'подпевают',
#   'поздним',
#   'вечером',
#   'врубают',
#   'жесткий',
#   'металл'],
#  ['вау', 'супер', 'ожидала'],
#  ['бесит', 'человек', 'пишет', 'бесит', 'уходит', 'офф'],
#  ['ничего', 'меняется'],
#  ['джеймс', 'афигеть', 'изменился'],
#  ['ученье', 'свет', 'неученье', 'приятный'],
#  ['прсонулась', 'уроку', 'ахахха', 'роучилась', 'урока', 'домой', 'збс'],
#  ['кажется', 'дух', 'делает', 'физика', 'тела'],
#  ['хочет', 'почитать', 'фф', 'большой'],
#  ['спокойной', 'ночи', 'волей', 'милый', 'классный', 'воля', 'прекрасный'],
#  ['милое',
#   'создание',
#   'написал',
#   'слов',
#   'твитере',
#   'оказывается',
#   'одно',
#   'твит',
#   'строница'],
#  ['неужели', 'нельзя', 'устроить', 'отвязную', 'вечеринку', 'алкоголя'],
#  ['азазазаза', 'просто', 'угрожает', 'd'],
#  ['старалась', 'd', 'одноклассница', 'твои', 'юн', 'спалила'],
#  ['старое', 'помянет'],
#  ['вижу', 'понравилась', 'цитата'],
#  ['даа',
#   'манчестер',
#   'сити',
#   'поставил',
#   'место',
#   'баварских',
#   'пижонов',
#   'знал'],
#  ['хочу', 'ходить', 'тренировки', 'снова', 'обожралась', 'd'],
#  ['думаю', 'группы', 'понедельник', 'зальют', 'купить', 'января'],
#  ['хотели',
#   'пойти',
#   'кино',
#   'мое',
#   'здоровье',
#   'запары',
#   'подружки',
#   'помешали',
#   'нам',
#   'посмотрим',
#   'олдбой',
#   'следующей',
#   'неделе'],
#  ['обиженно', 'бл', 'люблю', 'свой', 'd', 'хотела', 'написать', 'отлично'],
#  ['прошу', 'проголосуйте', 'спасибо'],
#  ['сашаааааа', 'урааа', 'зря', 'голосовали', 'ира', 'счастлива'],
#  ['кем',
#   'часто',
#   'общаешься',
#   'тви',
#   'кейком',
#   'каждый',
#   'день',
#   'пузей',
#   'виксом',
#   'улыбашой'],
#  ['денег', 'подарки', 'грустно', 'ладно', 'смогу', 'подарить'],
#  ['опыт',
#   'просто',
#   'танцуй',
#   'пока',
#   'молодой',
#   'надоест',
#   'захочется',
#   'тихой',
#   'комфортной',
#   'жизни'],
#  ['конце',
#   'любой',
#   'фразы',
#   'поставить',
#   'смайлик',
#   'это',
#   'автоматически',
#   'делает',
#   'её',
#   'дружелюбной',
#   'даёт',
#   'неё',
#   'обидеться',
#   'тупое',
#   'уёбище'],
#  ['влюбительное',
#   'воскресенье',
#   'просто',
#   'выспаться',
#   'ууухххххх',
#   'день',
#   'день'],
#  ['чаще',
#   'чаще',
#   'посещает',
#   'мысль',
#   'составить',
#   'график',
#   'дня',
#   'стараться',
#   'нему',
#   'жить',
#   'это',
#   'хороший',
#   'повод',
#   'купить',
#   'новый',
#   'ежедневник'],
#  ['спасибо', 'тебе', 'удачи', 'уроками', 'з'],
#  ['это',
#   'ирония',
#   'человека',
#   'побывавшего',
#   'шкуре',
#   'эйчара',
#   'жизненный',
#   'опыт'],
#  ['временами', 'тож', 'хочу', 'планируешь', 'пока'],
#  ['вместо',
#   'тысячи',
#   'слов',
#   'всем',
#   'доброго',
#   'сладкого',
#   'нежноого',
#   'утра',
#   'love',
#   'you'],
#  ['какие', 'молодые', 'учителя'],
#  ['ах', 'зима', 'вона'],
#  ['muslimkai',
#   'мечтала',
#   'стать',
#   'послом',
#   'мира',
#   'разочаровывайтесь',
#   'весь',
#   'мир'],
#  ['превращаешься', 'врача', 'это', 'необратимо'],
#  ['никто', 'придет', 'огонек', 'страха', 'сожженным', 'имя'],
#  ['пошел',
#   'устраивать',
#   'фотосессию',
#   'зимы',
#   'фотки',
#   'покажу',
#   'вк',
#   'have',
#   'a',
#   'nice',
#   'day'],
#  ['менялся', 'поменял', 'заражал', 'безысходным', 'черным', 'цветом', 'боись'],
#  ['ааа', 'скоро', 'дядя', 'должен', 'жвачку', 'европы', 'привезти'],
#  ['говорила', 'любимой', 'довела', 'слез', 'd'],
#  ['мою', 'любимую', 'физру', 'отрабатывать', 'придётся', 'незадача'],
#  ['иду', 'грозу', 'бодрячком', 'пацанчеги', 'бодрячком'],
#  ['ура'],
#  ['уууу', 'доярку', 'хацапетовки', 'смотрела'],
#  ['ой',
#   'планы',
#   'завтра',
#   'слышала',
#   'пархимчик',
#   'главное',
#   'посоветовала',
#   'фильм',
#   'посмотреть',
#   'лимончик'],
#  ['джуб', 'стороны', 'остальном'],
#  ['ага',
#   'лет',
#   'точно',
#   'ferrari',
#   'привезенная',
#   'мамой',
#   'италии',
#   'заплакал',
#   'счастья',
#   'купили'],
#  ['слааа', 'украине'],
#  ['доброе', 'день', 'должен', 'круче', 'хорошими', 'эмоциями'],
#  ['любой', 'непонятной', 'борщ'],
#  ['смотрю', 'плачу', 'ржу', 'd', 'благовещенск'],
#  ['маэстро',
#   'это',
#   'здорово',
#   'цель',
#   'пианомании',
#   'действии',
#   'искусство',
#   'массы',
#   'действует'],
#  ['незаконно', 'просто', 'вся', 'суть', 'сериала', 'd'],
#  ['очень', 'говорят', 'очень', 'нг', 'придти'],
#  ['человек',
#   'отвергающий',
#   'руку',
#   'помощи',
#   'обиды',
#   'которую',
#   'помнит',
#   'минимум',
#   'глуп'],
#  ['мире',
#   'люди',
#   'которые',
#   'держат',
#   'компьютерную',
#   'мышку',
#   'левой',
#   'руке'],
#  ['добрым', 'утром', 'дорогие', 'друзья'],
#  ['пришла',
#   'брату',
#   'мыться',
#   'просит',
#   'смотреть',
#   'стесняется',
#   'ммммммммммм'],
#  ['надоело', 'дни', 'считать', 'лучше', 'завтра', 'профком', 'украшу'],
#  ['говорят',
#   'могу',
#   'написать',
#   'методичку',
#   'день',
#   'влюбить',
#   'программиста',
#   'юриста'],
#  ['отличное', 'настроение', 'улице', 'снежок'],
#  ['продаю', 'очень', 'быстро', 'легко', 'копится', 'душа', 'нужнее'],
#  ['странно', 'ходили', 'всем', 'этажам', 'могла', 'видеть', 'd'],
#  ['нашла',
#   'блокноте',
#   'прошлый',
#   'год',
#   'написали',
#   'блокнот',
#   'автор',
#   'знаем'],
#  ['тебе', 'красивого', 'грустного', 'жана', 'расстраивалась'],
#  ['завтра', 'идем', 'получать', 'зачет', 'демографии'],
#  ['прекрасно',
#   'каждый',
#   'день',
#   'буду',
#   'ходить',
#   'ненакрашеной',
#   'школу',
#   'мальчикам',
#   'нравится',
#   'ураура'],
#  ['тащемто', 'седьмая', 'секунда', 'белое', 'платье', 'х'],
#  ['сегодня',
#   'решил',
#   'восстановить',
#   'традицию',
#   'встречать',
#   'рассвет',
#   'велосипеде',
#   'зимой',
#   'ещё',
#   'делал'],
#  ['вчера',
#   'всем',
#   'посетили',
#   'выставку',
#   'юлианны',
#   'русаковой',
#   'особняк',
#   'артхаусу',
#   'этажа',
#   'внутренней',
#   'отделки',
#   'класс',
#   'очень',
#   'понравилось',
#   'мощь'],
#  ['ещё', 'ночи', 'желал'],
#  ['учишься'],
#  ['тебе', 'нравится', 'классов', 'нравится', 'симпатичны'],
#  ['ого', 'делаю', 'мальчика', 'болтать', 'всеми'],
#  ['андрей',
#   'приготовил',
#   'сюрприз',
#   'говорит',
#   'уууух',
#   'любопытство',
#   'распирает'],
#  ['сегодня',
#   'моей',
#   'анютки',
#   'день',
#   'рождения',
#   'красавица',
#   'праздником',
#   'любимая',
#   'тебе'],
#  ['кровать', 'капот', 'время', 'ждет'],
#  ['просто',
#   'заботимся',
#   'твоем',
#   'здоровье',
#   'мед',
#   'собираю',
#   'практикую',
#   'приготовление',
#   'домашнего',
#   'вина'],
#  ['поставят', 'хотя', 'могут', 'ахахахаах', 'd'],
#  ['нужна',
#   'тебе',
#   'ёлка',
#   'новый',
#   'год',
#   'это',
#   'главный',
#   'атрибут',
#   'нового',
#   'года'],
#  ['таак', 'тема', 'примерно', 'час', 'приедет', 'торопиться'],
#  ['всё', 'угодно', 'пиздюлей', 'получит'],
#  ['спискам', 'молодцы'],
#  ['ясно', 'значит', 'тобой', 'разница', 'час', 'ща'],
#  ['твит', 'моей', 'строчки'],
#  ['днём', 'рождения', 'счастья', 'здоровья'],
#  ['самые',
#   'интересные',
#   'фильмы',
#   'появляются',
#   'приближением',
#   'сессии',
#   'экзаменов'],
#  ['могу', 'скоро', 'репетитору', 'позвоню'],
#  ['поделись', 'мной', 'профессиональными', 'секретами'],
#  ['захотел', 'плюнуть', 'обхаркал', 'куртку', 'сигу', 'съел'],
#  ['ева', 'девушка', 'поддерживает', 'твой', 'внутресоциальный', 'статус'],
#  ['вообще',
#   'удивлен',
#   'играют',
#   'учитывая',
#   'долг',
#   'долге',
#   'кушала',
#   'команда',
#   'холле',
#   'отеля'],
#  ['лучше', 'мной', 'ахаха'],
#  ['секса', 'читатели'],
#  ['главное',
#   'ниче',
#   'звинело',
#   'ходьбе',
#   'пониженым',
#   'функционалом',
#   'айс',
#   'ваще'],
#  ['это', 'машка', 'очень', 'хорошо', 'рисует', 'хорошая', 'подруга'],
#  ['какое', 'самое', 'заветное', 'желание'],
#  ['буду', 'делать', 'закончу', 'поэтому', 'решила', 'послушать', 'музыку'],
#  ['лезгинка', 'африке'],
#  ['тоттэнэм', 'сити', 'забывать'],
#  ['норм', 'сходили'],
#  ['знал', 'это', 'неизбежно', 'gt'],
#  ['автобусы',
#   'начнут',
#   'делать',
#   'высоких',
#   'людей',
#   'поспать',
#   'gt',
#   'lt',
#   'd'],
#  ['купила',
#   'скраб',
#   'тела',
#   'сзади',
#   'написано',
#   'эффект',
#   'кожа',
#   'нежная',
#   'новая',
#   'аж',
#   'страшно',
#   'стало',
#   'd'],
#  ['спать', 'завтра', 'вставать', 'ранооо', 'всем', 'спокойной', 'ночки'],
#  ['это',
#   'семинар',
#   'социальному',
#   'проектированию',
#   'слушали',
#   'ересь',
#   'возмущались',
#   'последних',
#   'сил'],
#  ['аееееееееееее', 'нирванееееееее', 'хахха', 'ааааа'],
#  ['ребят', 'помогите', 'активнее', 'лентa'],
#  ['типя', 'спасибо', 'ульке', 'люблю', 'ульку'],
#  ['детского', 'ада', 'туда', 'вряд', 'попадешь'],
#  ['краснодарские',
#   'бабушки',
#   'настолько',
#   'суровы',
#   'лидия',
#   'аркадьевна',
#   'случайно'],
#  ['ооо', 'началась', 'война', 'цен', 'устройства', 'радует'],
#  ['ахах', 'верно', 'верно'],
#  ['пришли',
#   'сегодня',
#   'выводу',
#   'требовательна',
#   'это',
#   'хорошо',
#   'посмотрим',
#   'позже',
#   'скажешь'],
#  ['выздоравливай', 'офигеть', 'далеко', 'd'],
#  ['засыпаю', 'улыбкой', 'лице', 'одного', 'всем', 'спокойной', 'ночи'],
#  ['часа', 'освобождение', 'великолепно'],
#  ['темноте',
#   'увидела',
#   'дверь',
#   'комнате',
#   'закрыта',
#   'врубалась',
#   'грохоту',
#   'квартиру'],
#  ['заметила',
#   'й',
#   'большой',
#   'буквы',
#   'написала',
#   'иначе',
#   'большого',
#   'уважения'],
#  ['дурная', 'голова', 'спать', 'дает', 'beeline', 'нравится', 'подводит'],
#  ['короче', 'опу'],
#  ['перестаньте',
#   'жаловаться',
#   'ваши',
#   'проблемы',
#   'переполняют',
#   'ваши',
#   'проблемы',
#   'это',
#   'ваши',
#   'проблемы',
#   'касаются'],
#  ['сдал', 'статы', 'жизнь', 'продолжается', 'скоро', 'пересдача', 'матфизике'],
#  ['постный',
#   'смысле',
#   'жрёте',
#   'одну',
#   'постную',
#   'буженину',
#   'постные',
#   'окорока'],
#  ['ищите', 'позитив', 'неприятность', 'казалось', 'неизбежна'],
#  ['прибедняйся', 'страхово'],
#  ['зая', 'въехал', 'столб', 'говорит', 'плохо', 'вожу'],
#  ['писк', 'следующего', 'года', 'лошади', 'торопитесь', 'модницы'],
#  ['ладно', 'тебе', 'нравится'],
#  ['люблю',
#   'кода',
#   'идет',
#   'снег',
#   'предаст',
#   'нам',
#   'новогоднее',
#   'настроение'],
#  ['любителей', 'леопарда'],
#  ['кошка', 'ходит', 'вечному', 'кругу'],
#  ['поверишь', 'некоторые', 'лица', 'аватарки', 'воруют', 'dominobank'],
#  ['хочу', 'ещё', 'кормили', 'вкусно', 'мышой', 'щёлкали', 'моим', 'носом'],
#  ['cегодня', 'получила', 'свой', 'первый', 'жизни', 'зачёт', 'информатике'],
#  ['это', 'глаза', 'это', 'велосипед', 'нарисованный', 'dd'],
#  ['получасовая', 'медитативная', 'композиция', 'переговорами', 'космонавтов'],
#  ['хочешь', 'будешь', 'это', 'просто', 'парень', 'шубе', 'ахаха'],
#  ['несколько',
#   'минут',
#   'отъезжаем',
#   'аэропорта',
#   'франкфурта',
#   'дабы',
#   'вылететь',
#   'амстердам'],
#  ['морской',
#   'бой',
#   'наверное',
#   'янукович',
#   'помогает',
#   'ющенку',
#   'решать',
#   'кроссворд'],
#  ['людиии', 'мурлыкать', 'кому', 'помурлыкать', 'ушко', 'd'],
#  ['устраивает', 'd'],
#  ['иностранцы', 'шоке'],
#  ['фигли', 'молчишь', 'давно', 'поболтали', 'тобой'],
#  ['вконтакте', 'вступайте'],
#  ['ой',
#   'лучше',
#   'показал',
#   'баланс',
#   'телефона',
#   'банковской',
#   'картой',
#   'интернет',
#   'пополнять',
#   'столько',
#   'услышал'],
#  ['точно', 'хочется'],
#  ['спокойной', 'ночи', 'спооооть', 'o', 'зеваю', 'гуднайт'],
#  ['готова', 'подписаться', 'каждым', 'словом'],
#  ['всё', 'хорошо'],
#  ['такие', 'мими'],
#  ['такое',
#   'сделают',
#   'невозможно',
#   'психану',
#   'ахаха',
#   'наушники',
#   'ещё',
#   'выдёргивали'],
#  ['знаю',
#   'человек',
#   'пока',
#   'зад',
#   'пнут',
#   'делать',
#   'буду',
#   'хдд',
#   'сколько',
#   'прожила',
#   'контакта',
#   'd'],
#  ['это', 'спросить', 'понимаю', 'это', 'борьбу', 'хамством'],
#  ['одна', 'пятничная', 'подборка', 'прекрасных', 'сотрудниц', 'cristanval'],
#  ['очень',
#   'крутой',
#   'день',
#   'встретил',
#   'старых',
#   'знакомых',
#   'братана',
#   'пол',
#   'года',
#   'виделись',
#   'говорят',
#   'очень',
#   'рады',
#   'видеть',
#   'приятно'],
#  ['читай'],
#  ['наташа', 'очень', 'красивые', 'глаза', 'хахахаха'],
#  ['нашла', 'старую', 'карту', 'памяти', 'ржу', 'пол', 'вечера', 'dd'],
#  ['отключи',
#   'нахуй',
#   'первый',
#   'день',
#   'бесилась',
#   'пока',
#   'нашла',
#   'отключить',
#   'оповещения'],
#  ['снишься', 'рядом', 'это', 'дин', 'сэм'],
#  ['сомневался', 'должна', 'победить'],
#  ['уроки',
#   'сделаю',
#   'равно',
#   'нахер',
#   'никому',
#   'сдался',
#   'карка',
#   'ушла',
#   'лент',
#   'встречи'],
#  ['таааак', 'франсе', 'отменяется', 'пойду', 'мозайку', 'пособираю'],
#  ['приятно', 'любимая', 'группа', 'лайкает', 'твой', 'коммент'],
#  ['клево',
#   'добавляю',
#   'напоминания',
#   'помощью',
#   'голоса',
#   'звоню',
#   'бесплатный',
#   'номер',
#   'робот',
#   'добавляет'],
#  ['хочу', 'такоооооооооой'],
#  ['очень',
#   'хочется',
#   'декабря',
#   'дальше',
#   'рождество',
#   'новый',
#   'год',
#   'сказка',
#   'волшебство'],
#  ['возбуждающий', 'гель', 'видел', 'd', 'взять', 'dddd'],
#  ['понял', 'прям', 'дедушка', 'моргоз', 'd'],
#  ['комплексуйте',
#   'рост',
#   'жру',
#   'ночам',
#   'такая',
#   'прям',
#   'красавиц',
#   'комплексуете'],
#  ['уборка', 'блин', 'достало', 'время', 'посмотреть'],
#  ['ничего', 'особенного', 'произошло', 'закрыли', 'объединили'],
#  ['ночи', 'прекрасная', 'наташечка', 'умилилась', 'ушла', 'спать'],
#  ['танк', 'официально', 'купить'],
#  ['зимой', 'льет', 'ведра'],
#  ['люблю', 'свой', 'класс', 'ребят', 'ахуенны'],
#  ['лучший', 'новогодний', 'подарок', 'зеленый', 'перекресток'],
#  ['весело', 'хулиган'],
#  ['обещала',
#   'показать',
#   'блюдо',
#   'keslermaria',
#   'купленное',
#   'оно',
#   'огромное'],
#  ['привет',
#   'привет',
#   'вернись',
#   'ко',
#   'смысл',
#   'могу',
#   'смотреть',
#   'счастлива'],
#  ['блиииин',
#   'жося',
#   'капец',
#   'везет',
#   'иду',
#   'нему',
#   'концерт',
#   'воскресение'],
#  ['ахахах', 'пока', 'желание', 'ахах'],
#  ['сижу', 'пока', 'выгнали'],
#  ['гитарист',
#   'утверждать',
#   'играет',
#   'лучше',
#   'сыграет',
#   'ваши',
#   'партии',
#   'нефиг',
#   'делать',
#   'gt'],
#  ['ууу', 'авсиевич', 'ночь', 'будем', 'празновать', 'др', 'ехууу', 'нам'],
#  ['новогодних', 'блюд', 'которые', 'изменят', 'вашу', 'жизнь', 'героин'],
#  ['понятно', 'сегодня', 'пары', 'это', 'равно', 'херня'],
#  ['чатрулет', 'высшая', 'штука', 'd', 'давно', 'смеялась'],
#  ['видео', 'вк', 'всякие', 'смотрю'],
#  ['очень', 'увлекательный'],
#  ['гореть', 'аду'],
#  ['эта', 'зима', 'зимней'],
#  ['спасибо', 'взаимно'],
#  ['подняли', 'посещаемость', 'стадионе', 'плюс', 'зритель'],
#  ['завтра', 'послезавтра', 'куплю', 'билет', 'марсов', 'мной'],
#  ['аднроид',
#   'пикнул',
#   'вывел',
#   'иконку',
#   'месяца',
#   'написал',
#   'time',
#   'to',
#   'bed',
#   'охренеть',
#   'заботливый',
#   'послушать'],
#  ['блин',
#   'шарфы',
#   'моей',
#   'позитивные',
#   'убейте',
#   'смогла',
#   'се',
#   'отказать',
#   'этазависимостьнеизлечима'],
#  ['ничего', 'раскрепостить'],
#  ['оой',
#   'подошел',
#   'ко',
#   'мандаринкой',
#   'говорит',
#   'вии',
#   'жду',
#   'скажет',
#   'лена'],
#  ['незаметно', 'весело', 'кладбища', 'дошли'],
#  ['утро', 'субботы', 'декабря', 'месяц', 'рождество'],
#  ['вся', 'музыка', 'очень', 'нравится', 'кого', 'похожи'],
#  ['утра',
#   'минус',
#   'уходя',
#   'работы',
#   'сказали',
#   'улице',
#   'минус',
#   'это',
#   'учуяла'],
#  ['кузей', 'кузя', 'мной', 'друг', 'профессиональной', 'камерой', 'находка'],
#  ['хаха', 'ийм', 'жижигхэн', 'юман', 'дээр', 'маргаан', 'бсымуу', 'gt', 'lt'],
#  ['учить', 'уроки', 'сижу', 'смотрю', 'ночной', 'дозор'],
#  ['дальше', 'ещё', 'глубже', 'сугроб', 'специально', 'поменял', 'ногой'],
#  ['эт', 'курсе', 'новости', 'собственно', 'узнала', 'знала'],
#  ['въвъъаъаъпъахахаъаъпххъаъаз', 'божи', 'dd', 'ахахааха'],
#  ['доброе',
#   'утро',
#   'танечка',
#   'отличного',
#   'выходного',
#   'дня',
#   'прекрасного',
#   'настроения'],
#  ['думаете', 'раньше', 'трава', 'зеленее'],
#  ['максимум', 'красавчик', 'з'],
#  ['ребят',
#   'извините',
#   'виде',
#   'парок',
#   'создаётся',
#   'ощущение',
#   'это',
#   'мешок',
#   'навозный'],
#  ['довели', 'щас', 'девчонки', 'психоз', 'накатанной', 'идет'],
#  ['пригласили', 'петь', 'рада', 'давно', 'хотела', 'побывать'],
#  ['аахахаххаа', 'понятно', 'нг', 'каков', 'клипа', 'ddd'],
#  ['даааа', 'позавидуешь', 'помойка'],
#  ['чувство',
#   'ла',
#   'назвала',
#   'валька',
#   'витей',
#   'сказала',
#   'валерий',
#   'упс',
#   'полтора',
#   'года',
#   'могла',
#   'запомнить'],
#  ['целом', 'пару', 'месяцев', 'завтракаю', 'радуюсь'],
#  ['впервые',
#   'услышал',
#   'scorpions',
#   'представил',
#   'высокого',
#   'худого',
#   'патлатого',
#   'вокалиста',
#   'увидел',
#   'фото',
#   'клаус'],
#  ['драка', 'катькой', 'уроке', 'просила', 'трогать', 'патлы'],
#  ['такое',
#   'высказывание',
#   'украине',
#   'спасибо',
#   'жителям',
#   'донбасса',
#   'президента',
#   'ананаса'],
#  ['пздц', 'напрягался', 'вроде'],
#  ['утро',
#   'сегодня',
#   'съездил',
#   'раменское',
#   'забрал',
#   'документы',
#   'подписал',
#   'важный',
#   'это',
#   'начало',
#   'дня'],
#  ['скоро', 'буду', 'свободееееен', 'сессии', 'начать', 'готовиться'],
#  ['тема', 'мир', 'открывается', 'новыми', 'гранями'],
#  ['дела', 'любимый', 'просто', 'офигееенно', 'поживаешь', 'настроение'],
#  ['посылаю', 'лучи', 'табуреток', 'сейкрида', 'seconds', 'to', 'mars'],
#  ['команда',
#   'центрального',
#   'офиса',
#   'встрече',
#   'владельцев',
#   'клубов',
#   'fitcurves',
#   'киеве',
#   'страна',
#   'должна',
#   'знать',
#   'своих',
#   'героев'],
#  ['социалисты',
#   'мусульмане',
#   'те',
#   'мир',
#   'всем',
#   'мире',
#   'это',
#   'должен',
#   'мир'],
#  ['спокойной', 'ночи', 'сладких', 'всем'],
#  ['это',
#   'последний',
#   'вечер',
#   'буду',
#   'портить',
#   'свой',
#   'желудок',
#   'маман',
#   'приезжает'],
#  ['развлекать'],
#  ['исполню',
#   'тебе',
#   'стиле',
#   'рэп',
#   'выложу',
#   'ютуб',
#   'скину',
#   'тебе',
#   'сюда'],
#  ['школе', 'поставили', 'диваны', 'd', 'валяются'],
#  ['запоминаем', 'моменты', 'камеры'],
#  ['оказывается', 'скучал'],
#  ['театре',
#   'долго',
#   'ждала',
#   'маму',
#   'уборной',
#   'поэтому',
#   'надела',
#   'шубу',
#   'свой',
#   'пуховик',
#   'ходила',
#   'вдоль',
#   'гардеробной',
#   'словами',
#   'царь',
#   'люди',
#   'ржали',
#   'd'],
#  ['больными', 'грешно', 'издеваться'],
#  ['новый', 'город', 'твонис', 'my', 'railway', 'заходи', 'гости'],
#  ['болит', 'поясница', 'говорю', 'столетняя', 'бабка'],
#  ['каждый', 'день', 'забит', 'ловлю', 'кайф', 'устаю', 'правда'],
#  ['залечить', 'душевные', 'раны', 'музыкой', 'книгой'],
#  ['улице', 'сказка', 'вообще', 'тихо', 'снег', 'нетронутый', 'лежит'],
#  ['футбольная', 'лента', 'праздником', 'сегодня', 'наш', 'день'],
#  ['повезло',
#   'встретил',
#   'такого',
#   'коллегу',
#   'понял',
#   'беспокойно',
#   'реагировать',
#   'следует',
#   'резкие',
#   'эмоции',
#   'лишнее'],
#  ['ночью', 'запретили', 'еда', 'снится'],
#  ['дождались',
#   'официальный',
#   'трейлер',
#   'иван',
#   'царевич',
#   'серый',
#   'волк',
#   'смотреть',
#   'всем',
#   'толи'],
#  ['дамы', 'прекрасны', 'спасибо', 'большое', 'поздравления'],
#  ['приснилось',
#   'блеать',
#   'упала',
#   'льду',
#   'катя',
#   'пришла',
#   'шок',
#   'дергнула',
#   'кровать'],
#  ['влюблена', 'саму', 'любимую'],
#  ['совестно', 'тебе', 'прогуливать', 'грешник', 'ахахах', 'насмешил', 'd'],
#  ['украсить', 'ёлку', 'лень', 'её', 'ставить'],
#  ['bobafop', 'фоткал', 'вышнем', 'волочке', 'ого', 'это', 'экипаж'],
#  ['благодарю', 'мешает', 'закажи'],
#  ['собой',
#   'закон',
#   'опсихиатрической',
#   'помощи',
#   'нашу',
#   'психиатрисеская',
#   'отменчется'],
#  ['доклад',
#   'околофутболу',
#   'отлично',
#   'антошка',
#   'похвалил',
#   'рефераты',
#   'готова',
#   'тему',
#   'писать'],
#  ['недель', 'осталось', 'жду', 'дождусь'],
#  ['хотя', 'это', 'изначально', 'хотела', 'рада'],
#  ['ихих', 'ничего', 'решил', 'подарки', 'забудь'],
#  ['твой', 'любимый', 'рецепт', 'повар'],
#  ['святая', 'борода', 'сенеки', 'd', 'остановите', 'мою', 'истерику'],
#  ['кожаными', 'сапогами', 'улице', 'нашли', 'лета', 'зима', 'канкуне', 'чо'],
#  ['написали', 'сообщение', 'твоими', 'ногами', 'вышла', 'отличная'],
#  ['парке',
#   'рядом',
#   'домом',
#   'сказочно',
#   'красиво',
#   'доброго',
#   'вечера',
#   'любимые'],
#  ['одна', 'снежинка', 'снег', 'снег'],
#  ['точнее', 'упала', 'сука', 'время', 'стрельб', 'прямо', 'бак'],
#  ['игрули', 'какие', 'гонки', 'установить', 'хочу', 'поганять'],
#  ['нажал',
#   'волшебную',
#   'кнопку',
#   'постинга',
#   'жуйка',
#   'жж',
#   'интересно',
#   'работает'],
#  ['бобец', 'дамблдор', 'ага', 'd'],
#  ['познакомьтесь', 'моими', 'кумирами', 'гарри', 'выносит', 'ахахахах'],
#  ['знаю', 'покупать', 'трансляцию', 'смотреть', 'ногомяче', 'одна', 'дилемма'],
#  ['блин', 'забавный', 'ящик', 'граватаре', 'зарегали', 'похоже'],
#  ['ухахахаха', 'жесть', 'крутота', 'смотреть', 'всем'],
#  ['дачу', 'ездить', 'сука'],
#  ['настоящий', 'романтик'],
#  ['др',
#   'любимой',
#   'жены',
#   'день',
#   'календаря',
#   'нашей',
#   'семье',
#   'хотя',
#   'празднуем',
#   'сегодня',
#   'км',
#   'друг',
#   'друга'],
#  ['это',
#   'клево',
#   'пуфиках',
#   'горы',
#   'кататься',
#   'сноуборде',
#   'научиться',
#   'приходить',
#   'домой',
#   'греться',
#   'какао',
#   'руке'],
#  ['хаха', 'ребенка', 'жалко'],
#  ['любви', 'тебе', 'твоим', 'близнецом', 'полагается', 'семейной', 'паре'],
#  ['доброй',
#   'ночи',
#   'всем',
#   'ленте',
#   'моей',
#   'ленте',
#   'андрадит',
#   'd',
#   'доброй',
#   'ночи',
#   'тебе'],
#  ['сидеть',
#   'тренерской',
#   'необычно',
#   'заходят',
#   'борцы',
#   'спрашивают',
#   'думают',
#   'директор',
#   'клуба'],
#  ['хаах', 'смотрю', 'многие', 'девочки', 'этим', 'пользуются'],
#  ['сегодня',
#   'таком',
#   'хорошем',
#   'настроении',
#   'против',
#   'уборки',
#   'истории',
#   'немецким'],
#  ['сапоги', 'йети', 'полностью', 'оправдывают', 'свое', 'название', 'буээ'],
#  ['кажется', 'немного', 'марихуаной'],
#  ['ничего', 'сегодня', 'отметите', 'полную'],
#  ['думала',
#   'туса',
#   'интересная',
#   'нам',
#   'заняться',
#   'нечем',
#   'наверно',
#   'кино',
#   'плйдем'],
#  ['конце', 'очень', 'прослезилась', 'это', 'дерьмо'],
#  ['результат', 'вполне', 'ничего', 'могём', 'лучше', 'бронзой'],
#  ['каждым', 'разом', 'больше', 'больше', 'начинаю', 'любить', 'человек'],
#  ['никогда',
#   'отвечаю',
#   'звонок',
#   'неожиданно',
#   'звонит',
#   'незнакомый',
#   'номер',
#   'звонка',
#   'такое',
#   'чувство',
#   'скрываюсь',
#   'фсб'],
#  ['работает', 'поражало', 'спорткоры', 'предсказывают', 'результаты'],
#  ['линдси',
#   'хорошая',
#   'лично',
#   'очень',
#   'нравятся',
#   'пара',
#   'никого',
#   'хочу',
#   'обидеть'],
#  ['понять',
#   'просто',
#   'собираюсь',
#   'пересмотреть',
#   'полностью',
#   'переосмыслить'],
#  ['сразу', 'предупредил', 'угораздило', 'мол'],
#  ['утверждаешь', 'хорошая', 'девочка', 'знаю', 'хочешь', 'd'],
#  ['саакашвили', 'премьеры'],
#  ['вообще',
#   'хотела',
#   'пойти',
#   'спать',
#   'семечки',
#   'встали',
#   'моем',
#   'пути',
#   'хд',
#   'd'],
#  ['иду', 'такая'],
#  ['окнами', 'каток', 'сижу', 'дома', 'давай', 'знакомится', 'женя', 'зовут'],
#  ['денечке', 'месяцев', 'большой', 'мужчинка'],
#  ['рома',
#   'малая',
#   'извращенка',
#   'душик',
#   'мимими',
#   'всё',
#   'тобой',
#   'понятно',
#   'мной',
#   'понятно'],
#  ['проверка', 'орфографии', 'рулит'],
#  ['ещё', 'ругаюсь'],
#  ['скучаю', 'вернись', 'ко', 'горячая', 'вода'],
#  ['солнушка',
#   'вполне',
#   'всё',
#   'понимаю',
#   'сама',
#   'часто',
#   'белу',
#   'свету',
#   'брожу'],
#  ['нашла', 'компьютере', 'разряда', 'вебка'],
#  ['романова',
#   'многое',
#   'нам',
#   'рассказала',
#   'чилоча',
#   'ставил',
#   'мины',
#   'поднимаясь',
#   'гору',
#   'd'],
#  ['лови', 'вк'],
#  ['еду', 'автобусе', 'поездки', 'конячках', 'слушаю', 'reelroad', 'хорошо'],
#  ['ч', 'говно', 'говно', 'долдны', 'жить', 'вместе', 'поймёшь'],
#  ['песня', 'года', 'января', 'телевизорах', 'страны'],
#  ['наверное', 'нужно', 'делать'],
#  ['умение', 'играть', 'ноктюрн', 'делает', 'человека', 'крутым'],
#  ['сна', 'бесконечное', 'пространство', 'завтра', 'забрало'],
#  ['блин',
#   'времена',
#   'одно',
#   'лицо',
#   'делаю',
#   'чисто',
#   'интуитивно',
#   'ещё',
#   'химики',
#   'делают',
#   'английский'],
#  ['любила', 'мультик'],
#  ['ахаххаха',
#   'єт',
#   'равно',
#   'день',
#   'впустую',
#   'знаний',
#   'набираешься',
#   'похвально',
#   'воооот',
#   'd'],
#  ['начинаю',
#   'писать',
#   'подобные',
#   'вещи',
#   'либо',
#   'отходят',
#   'либо',
#   'перестают',
#   'смотреть'],
#  ['слыш', 'забыла', 'случаем', 'd'],
#  ['ахаха', 'инет', 'открыт', 'дорамку', 'качаю'],
#  ['і',
#   'подумав',
#   'жаль',
#   'субарік',
#   'тато',
#   'зараз',
#   'був',
#   'би',
#   'самийй',
#   'сезон'],
#  ['шатаю', 'людей', 'бананов', 'бананов', 'd'],
#  ['бридж', 'самого', 'интернет', 'хреново', 'работает'],
#  ['дома', 'лучше', 'делают'],
#  ['посчитала',
#   'лайки',
#   'своей',
#   'странице',
#   'лайкомере',
#   'результаты',
#   'картинке',
#   'запускайте'],
#  ['узелок',
#   'развяжется',
#   'узелок',
#   'завяжется',
#   'любовь',
#   'кажется',
#   'людей',
#   'этаж',
#   'вечеринка'],
#  ['дабы', 'уподобляться', 'производителям', 'чайнафонов'],
#  ['зря',
#   'хуйней',
#   'шутите',
#   'историй',
#   'наблюдал',
#   'режиме',
#   'рил',
#   'времени',
#   'работе',
#   'русскими',
#   'которые',
#   'разбивались'],
#  ['патаму', 'латна', 'проста', 'хатил', 'навязываться'],
#  ['очень', 'хочу', 'туда', 'скидка', 'двоих', 'желающие'],
#  ['хохохо', 'эт', 'молодцы', 'бунт', 'устроили', 'достала', 'физичка'],
#  ['поздравляю', 'тысячника', 'жди', 'ночью'],
#  ['отличный', 'определенно', 'нравится'],
#  ['кстати', 'часа', 'сплю', 'высыпаюсь'],
#  ['бен', 'отвлёк', 'мартина', 'звонком', 'отца', 'воспользовался', 'моментом'],
#  ['те',
#   'предъявляет',
#   'эмм',
#   'сугубо',
#   'личное',
#   'дело',
#   'равно',
#   'перестану',
#   'читать',
#   'лайкать',
#   'твой',
#   'инстаграм'],
#  ['внка', 'фейтоте', 'упарывает', 'всё', 'сильнее'],
#  ['иннах', 'своими', 'красивее', 'd', 'мб', 'лера', 'заценит', 'уверена'],
#  ['посетила', 'мысль', 'lua', 'это', 'perl', 'человеческим', 'лицом'],
#  ['сестра',
#   'комнате',
#   'дверь',
#   'напугать',
#   'подкрадываюсь',
#   'ору',
#   'всё',
#   'ахуела'],
#  ['оперативная',
#   'служба',
#   'рамблера',
#   'восстановила',
#   'мою',
#   'почту',
#   'лучи',
#   'добра'],
#  ['хороший', 'вопрос', 'причём', 'положено'],
#  ['моментально', 'поднять', 'тебе', 'настроение', 'любимый'],
#  ['каждого', 'такие', 'просто', 'ненавидишь', 'согласитесь'],
#  ['радует',
#   'планшет',
#   'сделан',
#   'коллаборации',
#   'google',
#   'обновления',
#   'приходят',
#   'быстро'],
#  ['мега',
#   'упрт',
#   'рок',
#   'радуга',
#   'пони',
#   'стиле',
#   'нового',
#   'альбома',
#   'постановка',
#   'белоснежка',
#   'гот',
#   'збс'],
#  ['драбблы', 'намного', 'лучших', 'спасибо', 'большое', 'ссылку'],
#  ['выздоравливай', 'няшка', 'наша', 'пиздец', 'скучно', 'сс'],
#  ['лучше', 'упасть', 'зимой', 'иметь', 'кривые', 'пальцы', 'жизнь'],
#  ['просто', 'хочу', 'рядом', 'тобой', 'новогоднюю', 'ночь'],
#  ['чувство', 'недели', 'ко', 'паре', 'сегодня', 'завтра', 'каааайф'],
#  ['оживи', 'тур', 'минута', 'далее'],
#  ['вспомнил',
#   'момент',
#   'попросили',
#   'писать',
#   'нормально',
#   'твиттерских',
#   'ошибок',
#   'подняла',
#   'кипишь',
#   'd'],
#  ['типичные',
#   'наши',
#   'стихи',
#   'кристиной',
#   'тату',
#   'сане',
#   'автографами',
#   'd'],
#  ['обожаю', 'димка', 'бакштеев', 'летсплее', 'включает', 'вебку', 'милый'],
#  ['удивительно', 'это', 'удивительно'],
#  ['ильхом', 'поете', 'раньше', 'весь', 'мир', 'знал'],
#  ['люблю', 'рекламы', 'машины', 'особенно', 'идут', 'друг', 'другом'],
#  ['боже', 'охуенный', 'мышцы', 'показывал', 'вены', 'видны', 'обнял'],
#  ['божи', 'первый', 'спасибо', 'приятно'],
#  ['типо', 'модель', 'фотограф', 'алёна', 'пилипчук', 'me'],
#  ['аа', 'говорит', 'красивая', 'хочет', 'мной', 'отношений', 'подумаю'],
#  ['писать',
#   'статус',
#   'джаббере',
#   'название',
#   'трека',
#   'плейера',
#   'признак',
#   'аськоёба'],
#  ['отличные', 'принципы', 'работы', 'желтой', 'журналистики'],
#  ['чая',
#   'еду',
#   'жалко',
#   'выбрасывать',
#   'тех',
#   'пор',
#   'чай',
#   'америке',
#   'говно'],
#  ['это', 'чушь', 'года', 'ребенок', 'мал', 'личность', 'пусть', 'тусит'],
#  ['фильм',
#   'приключения',
#   'пространстве',
#   'времени',
#   'целом',
#   'показывают',
#   'пришло'],
#  ['всеее',
#   'похууууй',
#   'сделан',
#   'мяяяяяса',
#   'самое',
#   'страшное',
#   'моооожеееет',
#   'случиться'],
#  ['мир',
#   'люди',
#   'пусть',
#   'день',
#   'буде',
#   'таким',
#   'легким',
#   'снег',
#   'фото',
#   'marusya'],
#  ['уххх', 'физике', 'конференция', 'прошла', 'отлично'],
#  ['сижу',
#   'второй',
#   'день',
#   'нюхаю',
#   'рубашку',
#   'лизыыы',
#   'эй',
#   'тебе',
#   'напоминает',
#   'считая',
#   'фоток',
#   'стене'],
#  ['чертовски', 'хорош'],
#  ['ребят',
#   'забывайте',
#   'сегодя',
#   'последний',
#   'день',
#   'голосования',
#   'mtvstars',
#   'one',
#   'direction'],
#  ['днем', 'рождения', 'кать', 'пусть', 'мечтаешь', 'обязательно', 'сбывается'],
#  ['веселый', 'подарок', 'новый', 'год'],
#  ['могу',
#   'найти',
#   'мужской',
#   'аромат',
#   'память',
#   'врезался',
#   'парфюм',
#   'самое',
#   'приятное'],
#  ['пока',
#   'отлично',
#   'складывается',
#   'ихи',
#   'жаль',
#   'рано',
#   'встал',
#   'ахах',
#   'занят'],
#  ['короче', 'лень', 'дальше', 'это', 'распутывать'],
#  ['логически',
#   'подумать',
#   'бросит',
#   'деятельность',
#   'ради',
#   'полета',
#   'космос',
#   'абсурд',
#   'dd'],
#  ['дика', 'имел', 'именно', 'тех', 'футболистов'],
#  ['стучит',
#   'ощущаешь',
#   'матерым',
#   'писателем',
#   'жаль',
#   'это',
#   'чувство',
#   'ценила'],
#  ['hey', 'jude', 'чешском', 'доставляет'],
#  ['поверишь',
#   'абсолютно',
#   'серьезно',
#   'поинтересовалась',
#   'сказать',
#   'укор',
#   'самолюбию'],
#  ['странно', 'сегодня', 'выспалась', 'правда', 'встала', 'должна', 'd'],
#  ['моем', 'мухосранске', 'выпал', 'снеееег', 'растаял', 'пока'],
#  ['красивая', 'упаковка', 'вкус', 'меняет', 'инфа'],
#  ['последняя',
#   'ночь',
#   'время',
#   'просто',
#   'летит',
#   'скоро',
#   'сдавать',
#   'курсач',
#   'пора',
#   'оформлять'],
#  ['крутой', 'плоский', 'дизайн', 'стиле', 'ios'],
#  ['поезд', 'москву', 'отправляется', 'скоро'],
#  ['пункт', 'наших', 'планов', 'осуществлен'],
#  ['википедию', 'почитали'],
#  ['бля',
#   'юбке',
#   'ходила',
#   'киданула',
#   'фотографию',
#   'твиттер',
#   'подумали',
#   'это',
#   'd'],
#  ['правда',
#   'сильно',
#   'заранее',
#   'начал',
#   'реально',
#   'дедлайнов',
#   'куча',
#   'времени',
#   'ответы',
#   'будут',
#   'приходить',
#   'ток',
#   'весной',
#   'летом'],
#  ['одна', 'традиция', 'год', 'играть', 'бильярд', 'этим', 'заняты'],
#  ['замуж',
#   'собралась',
#   'го',
#   'костю',
#   'тебе',
#   'истории',
#   'рассказывать',
#   'жизни',
#   'учить'],
#  ['это', 'точно', 'срать', 'весь', 'мир', 'кроме', 'родных', 'близких'],
#  ['ах', 'тыж', 'кучка', 'любимая'],
#  ['помоему', 'никогда', 'переставала', 'тусить', 'старуха'],
#  ['че',
#   'юзаешь',
#   'кнопку',
#   'share',
#   'кстати',
#   'советую',
#   'включить',
#   'русская',
#   'озвучка',
#   'ужасная',
#   'ппц'],
#  ['блин',
#   'такая',
#   'хорошенькая',
#   'тебе',
#   'должны',
#   'пятерки',
#   'рисовать',
#   'умная',
#   'кстати'],
#  ['какие',
#   'похожие',
#   'моськи',
#   'старательно',
#   'крутит',
#   'педали',
#   'годами',
#   'это',
#   'меняется',
#   'бесценен'],
#  ['утренние', 'новости', 'комментарии'],
#  ['выше', 'это', 'баба', 'адовая'],
#  ['залезла', 'маками', 'пограничники'],
#  ['оп', 'прокольчик', 'вышел'],
#  [],
#  ['просто', 'вроде', 'мистер', 'оказывается', 'таня'],
#  ['привет', 'спасибо', 'читаешь'],
#  ['точно', 'футболку', 'заметила', 'другая', 'хах'],
#  ['гномов', 'женщины', 'просто', 'немного', 'бородатые', 'd'],
#  ['глюк', 'значит', 'извини', 'просто', 'написано', 'анфолловила'],
#  ['прикинте', 'риверуша', 'звонила'],
#  ['аааааааааа', 'хахахах', 'аххахахха', 'убила', 'убила', 'нахер', 'убрала'],
#  ['нраву', 'эта', 'черепушечка', 'мм', 'добавляет', 'антураж', 'х'],
#  ['хотела', 'рассказать', 'историю', 'всему', 'миру', 'читателей', 'd'],
#  ['молодежь', 'против', 'чиновников', 'депутатов'],
#  ['знала', 'таким', 'образом', 'дверь', 'домофонную', 'открывают', 'хаха'],
#  ['двушку', 'пальнул', 'последнюю', 'неделю', 'будем', 'надеяться'],
#  ['мороженка', 'каштан', 'больше', 'ничего', 'счастья'],
#  ['особенный',
#   'вид',
#   'ушей',
#   'd',
#   'некоторые',
#   'вакуумные',
#   'наушники',
#   'моих',
#   'ушах',
#   'просто',
#   'держатся'],
#  ['доброго', 'дня', 'уфимцы', 'twitter'],
#  ['малыш',
#   'большой',
#   'шалунишка',
#   'очень',
#   'активный',
#   'разу',
#   'грустный',
#   'кот',
#   'фотографировал',
#   'оой'],
#  ['дивны',
#   'дела',
#   'твои',
#   'господи',
#   'это',
#   'удивительно',
#   'просто',
#   'светло'],
#  ['гачинается', 'расход', 'люди', 'мерзнут', 'трусах', 'халате'],
#  ['запомните', 'героина', 'сорта', 'эй', 'ванильки'],
#  ['ахахахах', 'пытаюсь', 'уличить', 'плохо', 'питаюсь', 'хорошо', 'питаешься'],
#  ['alexsuperworld',
#   'пиздецки',
#   'ржачный',
#   'летсплейщик',
#   'слов',
#   'просто',
#   'уссыкаюсь'],
#  ['вчера',
#   'день',
#   'прошел',
#   'интересно',
#   'спасибо',
#   'моим',
#   'друзьям',
#   'отдельное',
#   'спасибо',
#   'азату'],
#  ['явно', 'красивше', 'йоко', 'будешь'],
#  ['кошечка', 'изизизиз', 'люблю', 'типя'],
#  ['дружинники', 'спасибо', 'приятно', 'работать', 'удачи', 'работе'],
#  ['сколько', 'дней', 'олимпиады'],
#  ['маленько', 'буду', 'смеяться', 'тюлень', 'понимаешь', 'аъаъаъаъ'],
#  ['приехала', 'открытый', 'урок', 'классике', 'приятно', 'люблю'],
#  ['пытаюсь', 'виноват', 'оно', 'прет', 'сторон', 'ddddd'],
#  ['получил',
#   'водительское',
#   'удостоверение',
#   'борьба',
#   'закончилась',
#   'битва',
#   'прошлом'],
#  ['голосуй',
#   'делай',
#   'джаред',
#   'переедет',
#   'тебе',
#   'жить',
#   'тебе',
#   'счастье',
#   'seconds',
#   'to',
#   'mars'],
#  ['заказал',
#   'угги',
#   'интернете',
#   'спортмастера',
#   'галерее',
#   'лично',
#   'видел',
#   'дурачек'],
#  ['выкидывание', 'старой', 'стиралки', 'это', 'сложный', 'процесс'],
#  ['время',
#   'англа',
#   'поговорили',
#   'политике',
#   'професиях',
#   'повырезали',
#   'какую',
#   'хрень',
#   'фоткали',
#   'оленей',
#   'приняла',
#   'вызов',
#   'скочеляса',
#   'подраться',
#   'флажками'],
#  ['веселой',
#   'фигней',
#   'никогда',
#   'занималась',
#   'нравится',
#   'это',
#   'обо',
#   'всем',
#   'мучает'],
#  ['очень', 'странно', 'тебе', 'поговорить'],
#  ['взломала', 'вк', 'одноклассницы', 'думаешь', 'твой'],
#  ['давхар', 'давхар', 'шалгана', 'шүү', 'нээрээ', 'сураг', 'сонссон'],
#  ['крч', 'скинул', 'ссылки', 'свои', 'фф', 'всем', 'похуй', 'норм'],
#  ['даааа',
#   'лёшкай',
#   'зубариком',
#   'болтали',
#   'прикинь',
#   'струихиным',
#   'помирились',
#   'всё',
#   'вернётся'],
#  ['шинэ', 'жилийн', 'ширээн', 'дээрээ', 'бvсгvйчvvддээ'],
#  ['говорил', 'нельзя', 'согласна'],
#  ['вторая',
#   'попытка',
#   'посмотреть',
#   'фильм',
#   'мстители',
#   'тк',
#   'первый',
#   'смотрела',
#   'дико',
#   'ужасном',
#   'качестве'],
#  ['братья', 'd'],
#  ['существенное', 'влияние', 'мою', 'орфографию', 'оказывает', 'гололед'],
#  ['скоро',
#   'украсишь',
#   'квартиру',
#   'новому',
#   'году',
#   'дома',
#   'появишься',
#   'вездесущая',
#   'наша',
#   'ню'],
#  ['фифе', 'сегодня', 'матчей', 'раза', 'забил', 'пикеша', 'это', 'знак', 'd'],
#  [],
#  ['это',
#   'самая',
#   'лучшая',
#   'темнота',
#   'бешенство',
#   'диване',
#   'моими',
#   'любимыми',
#   'весело'],
#  ['ох', 'бабл', 'везде', 'найдешь', 'свяжешь', 'сехуном', 'd'],
#  ['просто', 'поржать', 'почитаю', 'гет'],
#  ['прихожу',
#   'работу',
#   'спрашиваю',
#   'хочется',
#   'именно',
#   'сегодня',
#   'кроме',
#   'алкоголя',
#   'угощаю'],
#  ['оно', 'серьезно', 'хорошее', 'других', 'дев', 'точно', 'хорошее'],
#  ['понравилось', 'видео', 'наш', 'праздничный', 'торт', 'мои', 'эмоции'],
#  ['абуби', 'лучше', 'ляжь', 'пораньше', 'хрен', 'проснешься', 'd'],
#  ['кровь',
#   'кавычках',
#   'имел',
#   'ввиду',
#   'ассоциации',
#   'ю',
#   'поменяются',
#   'местами'],
#  ['кот',
#   'любит',
#   'bmw',
#   'сегодня',
#   'весь',
#   'день',
#   'документах',
#   'лежит',
#   'нутром',
#   'чует',
#   'крутые',
#   'тачки'],
#  ['подтверждаю', 'покупались'],
#  ['чтоо', 'придёт', 'сегодня', 'мск', 'нашу'],
#  ['нэг',
#   'эмээ',
#   'хандраад',
#   'байх',
#   'юм',
#   'яаж',
#   'байна',
#   'дагасан',
#   'чинь',
#   'буцаж',
#   'дагасан',
#   'байх',
#   'юм'],
#  ['фонтане', 'вместо', 'воды'],
#  ['десять', 'это', 'интересно'],
#  ['взбодриться', 'утром', 'приеданий', 'чай', 'мятный', 'леденец'],
#  ['шпинат', 'измажу', 'твою', 'квартиру', 'корицей'],
#  ['полезные',
#   'привычки',
#   'осваиваю',
#   'посуду',
#   'мыть',
#   'перчатках',
#   'снимать',
#   'птицы',
#   'кожу',
#   'полезное',
#   'делаете'],
#  ['хмм', 'подумать', 'ещё', 'подъебать'],
#  ['ахах', 'че', 'наоборот', 'нормально'],
#  ['барселона',
#   'селтик',
#   'барселона',
#   'выиграла',
#   'селтик',
#   'выйдет',
#   'плей',
#   'офф',
#   'жаль',
#   'мест',
#   'играл'],
#  ['рейтинг', 'пар', 'wgm', 'кунтория', 'канин', 'юнчжи', 'тэын', 'явсесказал'],
#  ['убери', 'крошка', 'крошки', 'осталась', 'крошка'],
#  ['иван', 'царевич', 'серый', 'волк', 'идем', 'кино', 'премьера', 'декабря'],
#  ['психологически',
#   'тебе',
#   'восемь',
#   'большой',
#   'можешь',
#   'конфетки',
#   'покупать'],
#  ['ладно',
#   'это',
#   'самых',
#   'культурных',
#   'безобидных',
#   'спамов',
#   'которые',
#   'встречал'],
#  ['какого',
#   'закона',
#   'хватает',
#   'твоей',
#   'стране',
#   'хотя',
#   'маленькое',
#   'избиение',
#   'животного',
#   'сажали',
#   'лет'],
#  ['считаю', 'преподавать', 'именно', 'c', 'отличие', 'платформы'],
#  ['asdfsadfsfd',
#   'друг',
#   'смогёт',
#   'поддержать',
#   'ахахаха',
#   'увидел',
#   'твит',
#   'верю'],
#  ['трудно',
#   'страшно',
#   'почувствовать',
#   'лишним',
#   'недавно',
#   'необходима',
#   'бля',
#   'это',
#   'правда'],
#  ['улыбнуло'],
#  ['доброго',
#   'хорошего',
#   'вечера',
#   'спасибо',
#   'большое',
#   'радуете',
#   'новыми',
#   'фото',
#   'публикациями',
#   'конкурсами',
#   'спасибо',
#   'большое',
#   'вашу'],
#  ['зооз',
#   'санжаа',
#   'гэдэг',
#   'мангааг',
#   'л',
#   'лав',
#   'бөх',
#   'байтугай',
#   'адгуусч',
#   'тогтоохгүй',
#   'юм',
#   'жил',
#   'бядныга',
#   'баясгаарайдаа'],
#  ['оооооо',
#   'қандай',
#   'жағымды',
#   'жаңалық',
#   'қазнеттің',
#   'тұлғалары',
#   'тимур',
#   'бектұр',
#   'жарайсың',
#   'жарайсың',
#   'дегендеріңіз',
#   'ртлаңыз'],
#  ['хорошо', 'кого', 'реально', 'любиш'],
#  ['привет', 'иннас', 'профиль', 'закрыт'],
#  ['радостью',
#   'литература',
#   'позволяет',
#   'пишу',
#   'ответ',
#   'вопрос',
#   'основе',
#   'статьи',
#   'писарева',
#   'базаров',
#   'допишу',
#   'спать',
#   'сразу'],
#  ['произошли',
#   'ещё',
#   'интересные',
#   'вещи',
#   'это',
#   'интересно',
#   'хотя',
#   'улыбнулти'],
#  ['эх',
#   'конфу',
#   'одессу',
#   'съездил',
#   'интересно',
#   'это',
#   'слишком',
#   'далеко',
# ...
#  ['следующая', 'фотка', 'мясом', 'блинами', 'фоткает', 'йогурты'],
#  ['ааяаа',
#   'зуун',
#   'жил',
#   'жиргэх',
#   'ереел',
#   'схан',
#   'бнаа',
#   'дагагчтай',
#   'блхын',
#   'тулд',
#   'гадаад',
#   'хэлээр',
#   'жиргэх',
#   'болох',
#   'баярлалаа',
#   'хее'],
#  ['забавно', 'тегу', 'постов', 'больше', 'тегу', 'всем', 'жуйке'],
#  ['вечера', 'сможете', 'увидеть', 'танцующую', 'соборной'],
#  ['согласен', 'здоровье', 'губить'],
#  ['это', 'говорит', 'норг', 'собственной', 'персоны', 'своему', 'd'],
#  ['кидай', 'номер', 'позвоню', 'спрошу', 'дела'],
#  ['улице',
#   'холодно',
#   'руки',
#   'мерзнут',
#   'тепло',
#   'вкусно',
#   'пахнет',
#   'свежей',
#   'пообедать'],
#  ['сегодня', 'прекрасный', 'день', 'крики', 'соседей', 'помешают'],
#  ['диржиии'],
#  ['родном', 'языке', 'полиглот', 'типа'],
#  ['дагамаар',
#   'санагдтал',
#   'буджаргал',
#   'урангоо',
#   'байхад',
#   'шинэхэн',
#   'жиргээч',
#   'болохоор',
#   'яадаг',
#   'хүмүүс',
#   'юм',
#   'бүр',
#   'ойлгохгүй',
#   'юм'],
#  ['целый',
#   'день',
#   'хожу',
#   'хорошим',
#   'настроением',
#   'друзей',
#   'сегодня',
#   'видно',
#   'день',
#   'печали',
#   'улыбнииииитесь'],
#  ['се', 'жизнь', 'удалась'],
#  ['нужна', 'тебе', 'ёлка', 'новый', 'год', 'даа', 'очень'],
#  ['никак',
#   'могу',
#   'понять',
#   'буду',
#   'сегодня',
#   'смотреть',
#   'лч',
#   'посплю',
#   'х'],
#  ['ураааа', 'нашёлся', 'человек', 'которым', 'гулять', 'звать', 'других'],
#  ['снежоок'],
#  ['светлого', 'образа', 'можем', 'лишиться'],
#  ['буду', 'завтро', 'весь', 'день', 'ждать'],
#  ['очень', 'скоро', 'москва', 'станет', 'похожа', 'киев'],
#  ['африканский', 'попец'],
#  ['смотри', 'd', 'узнаю', 'смотришь', 'веняй', 'd'],
#  ['часто', 'ходишь', 'клубы', 'вообще', 'хожу'],
#  ['аська', 'сдохла', 'это', 'последний', 'звонок'],
#  ['имела', 'ввиду', 'лето', 'весну', 'остальное', 'пусть', 'остается'],
#  ['уххх', 'мигуль', 'найдешь', 'знаменке', 'джонни', 'деппа', 'сообщи', 'd'],
#  ['другом', 'доме', 'разных', 'концах', 'города', 'живут'],
#  ['збагойненько', 'скоро', 'приду', 'сказал'],
#  ['пожалуй', 'пора', 'спать', 'дождусь', 'тех', 'снов', 'которые', 'нужны'],
#  ['наряжать', 'вышлешь', 'костюм', 'москвы'],
#  ['бывают',
#   'парни',
#   'которым',
#   'невозможно',
#   'отказать',
#   'автографе',
#   'делают',
#   'наверное',
#   'читают',
#   'твиттер'],
#  ['отвечу', 'танцем'],
#  ['уахахахаха',
#   'бәрін',
#   'айтыңыз',
#   'бірін',
#   'айтыңыз',
#   'өзіңіз',
#   'жүректен',
#   'сүйетін',
#   'һәм',
#   'үнемі',
#   'тілге',
#   'тиек',
#   'ететін',
#   'орынды',
#   'алдық'],
#  ['утро', 'телефон', 'запрашивает', 'puk', 'код', 'пьянка', 'удалась'],
#  ['ооо', 'завтра', 'приду', 'будут', 'фотки', 'фотки', 'фотки'],
#  ['mtv', 'смотрела', 'little', 'mix', 'фанат', 'нравятся', 'песни'],
#  ['утром', 'греет', 'байка', 'любимого', 'вся', 'пахну'],
#  ['окном',
#   'зима',
#   'майдане',
#   'происходит',
#   'малышкой',
#   'дома',
#   'смотрим',
#   'отпуск',
#   'обмену',
#   'благодать'],
#  ['азаззааззаюя', 'рад', 'дела'],
#  ['серия', 'дикого', 'ангела', 'держись', 'настя', 'сможешь'],
#  ['ахахахахахахахахахахахахахахахахаха', 'нууу', 'спааасииибооо'],
#  ['днём', 'рождения', 'пусть', 'твои', 'мечты', 'сбудутся'],
#  ['сказали', 'модель', 'хорошо', 'вк', 'виден', 'рост'],
#  ['почему',
#   'легче',
#   'стало',
#   'настроение',
#   'поднялось',
#   'стоило',
#   'послать',
#   'жопу'],
#  ['ладно', 'ими', 'позабавлю'],
#  ['кароч',
#   'сделаю',
#   'тоннель',
#   'получится',
#   'завтра',
#   'удачи',
#   'эксперименте'],
#  ['аха', 'мама', 'сказала', 'идти', 'школу', 'd'],
#  ['выходные',
#   'пройдут',
#   'ураа',
#   'особенно',
#   'теми',
#   'кем',
#   'виделась',
#   'очень',
#   'давно',
#   'больше',
#   'месяца'],
#  ['знаю', 'астане', 'жить', 'ахуенно', 'это', 'плюсов', 'девушки', 'красивые'],
#  ['будешь', 'возмущаться', 'выложу', 'ту', 'самую', 'фотку', 'твою'],
#  ['поскорее', 'пришли', 'мои', 'любимые', 'диски', 'queen'],
#  ['жаль', 'лучше', 'некоторые', 'снимают', 'зеленом', 'фоне'],
#  ['итоге', 'повалила', 'витю', 'снег', 'полностью', 'забросала', 'снегом'],
#  ['скоты', 'полные', 'день', 'забуду'],
#  ['обновился', 'pcmanfm', 'странно', 'вроде', 'говорили', 'оно', 'rip'],
#  ['зранку', 'заходила', 'інста', 'почнем', 'з', 'цього'],
#  ['сегодня', 'дико', 'обрадовала'],
#  ['закон', 'бумеранга', 'работает', 'явно', 'случаях'],
#  ['кириллом',
#   'костюмы',
#   'спортивные',
#   'одинакавые',
#   'ахах',
#   'штаны',
#   'просрала',
#   'шк'],
#  ['вчера',
#   'курнул',
#   'сижку',
#   'сходить',
#   'ума',
#   'париться',
#   'этому',
#   'поводу',
#   'игре',
#   'больше',
#   'отскочили',
#   'додавили'],
#  ['здоровье'],
#  ['правильно'],
#  ['большой',
#   'мазоль',
#   'вкусные',
#   'торта',
#   'местов',
#   'пирожок',
#   'повидлой',
#   'd'],
#  ['будь', 'моим', 'жиной', 'буду', 'лубит', 'типя', 'd'],
#  ['сколько', 'тебе', 'kitkat', 'мало', 'хомяк'],
#  ['проснулась', 'таки', 'жаль', 'часа', 'четыре', 'спала'],
#  ['збс', 'херня', 'асе', 'знаю', 'сколько', 'людей', 'подписано'],
#  ['такая', 'классная', 'маленькая', 'пупсяш', 'косичками', 'тебе', 'идет'],
#  ['недорогие',
#   'квартиры',
#   'сутки',
#   'минске',
#   'снять',
#   'сайт',
#   'пользуюсь',
#   'этим',
#   'вариантом'],
#  ['это', 'первый', 'юбилей', 'твиттере', 'это', 'ровно', 'твитт'],
#  ['всем',
#   'доброе',
#   'утро',
#   'збс',
#   'покурить',
#   'трусах',
#   'вышел',
#   'холода',
#   'аж',
#   'дети',
#   'яйцах',
#   'запищали'],
#  ['ретвит', 'считаешь', 'самое', 'главное', 'это', 'прямые', 'руки'],
#  ['сгущенка', 'дома'],
#  ['спасибо', 'прелесть'],
#  ['приятности'],
#  ['хорошо',
#   'помню',
#   'твою',
#   'идею',
#   'давайте',
#   'рисовать',
#   'комиксы',
#   'сделаем',
#   'революцию'],
#  ['вже',
#   'знаю',
#   'що',
#   'подарю',
#   'альоні',
#   'днюху',
#   'сухаааріки',
#   'ахахах',
#   'альона',
#   'буде',
#   'рада',
#   'ddd'],
#  ['ахаха', 'дааа', 'вену', 'пытался', 'прокусить'],
#  ['суббота',
#   'сложный',
#   'день',
#   'начинается',
#   'истерического',
#   'смеха',
#   'истории'],
#  ['нового', 'года', 'осталось', 'часа'],
#  ['сегодня', 'курсе', 'ребята', 'норвегии', 'выиграли', 'эстафету', 'это'],
#  ['странный', 'день', 'сегодня', 'ожидала'],
#  ['боже',
#   'светлана',
#   'владимировна',
#   'вами',
#   'классно',
#   'просто',
#   'обо',
#   'всем',
#   'поболтать',
#   'посмеяться',
#   'люблю'],
#  ['бывший', 'засмотрелся', 'ржала', 'слёз', 'всё', 'таки', 'немного'],
#  ['такие', 'маршрутчики', 'встречаются', 'каждый', 'день'],
#  ['d', 'просто', 'увидела', 'твит', 'идешь', 'школу', 'учусь'],
#  ['стоит', 'нам', 'поменять', 'аватарку', 'группы'],
#  ['волки', 'луну', 'бросаются', 'волкам', 'небо', 'хочется'],
#  ['это', 'насколько', 'бесчувственной', 'почувствовать', 'секс'],
#  ['больные', 'голову'],
#  ['погуляйте',
#   'сегодня',
#   'мной',
#   'нибууудь',
#   'знакомые',
#   'люди',
#   'погуляйте',
#   'd'],
#  ['вид', 'окна', 'знаю', 'почему', 'снег', 'делает', 'счастливого', 'ребёнка'],
#  ['опэнспейсе', 'раздался', 'храп', 'понял', 'трудовая', 'неделя', 'окончена'],
#  ['ничего', 'просто', 'хочу', 'перемен', 'dd', 'хотя', 'хочу', 'd'],
#  ['ебануться',
#   'samsung',
#   'galaxy',
#   'note',
#   'стоит',
#   'покупал',
#   'тысячу',
#   'зотя',
#   'это',
#   'летом',
#   'конда',
#   'вышел'],
#  ['чувак', 'рядом', 'нпзвал', 'своего', 'друга', 'неправильная', 'жопа', 'd'],
#  ['началу', 'буду', 'стесняться', 'писать', 'первый', 'всмысле'],
#  ['добрым', 'утром', 'спалось'],
#  ['кристину', 'замужнюю', 'моника', 'занята'],
#  ['вообще', 'отдельный', 'разговор', 'd', 'зимой', 'поедешь'],
#  ['домаааааа', 'очень', 'замерзла', 'сижу', 'отогреваюсь'],
#  ['прикинь',
#   'человек',
#   'атлантике',
#   'новый',
#   'год',
#   'блин',
#   'зря',
#   'написал',
#   'наверное',
#   'звонит',
#   'туда'],
#  ['вчера',
#   'костей',
#   'угорали',
#   'польской',
#   'd',
#   'забыла',
#   'кстати',
#   'напомнить',
#   'сегодня'],
#  ['взлетаем', 'курс', 'мск', 'всем', 'спасибо', 'новых', 'встреч'],
#  [],
#  ['побегу', 'равно', 'приду', 'часов', 'семь', 'запуска', 'хули'],
#  ['нихрена', 'жарко', 'замерзала', 'd'],
#  ['расписала',
#   'древнейшую',
#   'скалу',
#   'вселенной',
#   'отвачал',
#   'мои',
#   'звонки',
#   'ривер',
#   'тролль',
#   'вселенского',
#   'масштаба'],
#  ['фестивале', 'пива', 'кассовым', 'сборам', 'превзошел', 'аватар'],
#  ['ахаха', 'люблю', 'обнимаю'],
#  ['будем', 'сдавать', 'классе', 'сочинение', 'мимими'],
#  ['пошлаааааа', 'зима'],
#  ['еду',
#   'студию',
#   'поработать',
#   'солнышко',
#   'хорошо',
#   'греет',
#   'гулять',
#   'хочется',
#   'проведет',
#   'вечер',
#   'пятницы'],
#  ['бесят',
#   'просто',
#   'ахахаха',
#   'хер',
#   'знает',
#   'найду',
#   'армянский',
#   'кинжал',
#   'начать',
#   'ножика',
#   'кухонного'],
#  ['час',
#   'ночи',
#   'сидеть',
#   'друзьями',
#   'кухне',
#   'угорать',
#   'тупым',
#   'бредом',
#   'пить',
#   'вино',
#   'люблю'],
#  ['след', 'выходных', 'димана', 'ведришко', 'посмотреть', 'заберу', 'сразу'],
#  ['сегодня',
#   'совершенно',
#   'случайно',
#   'прогулялись',
#   'd',
#   'снежки',
#   'поиграли',
#   'сугроб',
#   'упали'],
#  ['имею',
#   'ввиду',
#   'результат',
#   'посмотри',
#   'атлетико',
#   'ведёёт',
#   'зениту',
#   'проиграй',
#   'всё',
#   'равно',
#   'вышли',
#   'цска',
#   'точно'],
#  ['знаешь', 'нужно', 'играть', 'банк', 'давай'],
#  ['хорошо', 'дома', 'кроватке', 'зная', 'сидят', 'школе'],
#  ['подушка',
#   'простыни',
#   'вся',
#   'постель',
#   'пахнет',
#   'тобой',
#   'люблю',
#   'родной'],
#  ['удовольствием', 'будем', 'смотреть', 'донецкий', 'шахтëр', 'тс', 'павлик'],
#  ['единственное',
#   'понравилось',
#   'фике',
#   'это',
#   'смерть',
#   'персонажа',
#   'лишней',
#   'вообще',
#   'фф',
#   'прекрасный'],
#  ['биг', 'сэнкс', 'май', 'диар', 'гёрлфрэнд'],
#  ['мене', 'вин', 'сив', 'd', 'щас', 'як', 'мужик', 'балакаю'],
#  ['любимого', 'защитника', 'поздравляю', 'днюхой', 'будь', 'скалой', 'даггер'],
#  ['продаже', 'билеты'],
#  ['темный',
#   'мир',
#   'это',
#   'вообще',
#   'комедия',
#   'просто',
#   'спец',
#   'эффекты',
#   'такие',
#   'сюжет',
#   'смешно',
#   'смотреть'],
#  ['смотрю', 'небо', 'оно', 'коричневое', 'крассиииввоо'],
#  ['дело', 'шоколадку', 'поспорили', 'd'],
#  ['отличный', 'ответ', 'ахаха'],
#  ['фб',
#   'сначала',
#   'спорил',
#   'форму',
#   'сторонниками',
#   'майдана',
#   'зацепили',
#   'сегодня'],
#  ['открыла',
#   'тане',
#   'аудиозаписи',
#   'кажется',
#   'перестанет',
#   'мной',
#   'общаться',
#   'd'],
#  ['вспомнила', 'приятные', 'дни', 'осени', 'тесака', 'вспомнила'],
#  ['новая',
#   'баба',
#   'откуда',
#   'вообще',
#   'нашел',
#   'елена',
#   'знаю',
#   'откуда',
#   'оппонентка'],
#  ['ой',
#   'ладно',
#   'это',
#   'редко',
#   'могу',
#   'красиво',
#   'рисовать',
#   'последняя',
#   'неделя',
#   'идет',
#   'успех'],
#  ['мальчики', 'такие', 'наивные', 'думают', 'девочки', 'наивные'],
#  ['рано', 'встает', 'здоровый', 'звездный', 'завтрак'],
#  ['это', 'взаимно', 'красиво', 'рисуешь', 'd', 'тодэ', 'тэхён', 'бож'],
#  ['пришел',
#   'девушке',
#   'домой',
#   'неё',
#   'стоит',
#   'линукс',
#   'неплохая',
#   'акустика',
#   'хм',
#   'это',
#   'девушка'],
#  ['привет',
#   'всем',
#   'моим',
#   'друзьям',
#   'добрыми',
#   'пожеланиями',
#   'новый',
#   'день'],
#  ['доброе', 'упороться', 'тебе', 'сегодня', 'следует'],
#  ['любовь', 'страдания', 'пивас', 'пить', 'собираюсь'],
#  ['самое', 'главное', 'тексты', 'внизу', 'русские'],
#  ['ахахаха', 'творила', 'лс', 'расскажи'],
#  ['вчера',
#   'прочим',
#   'биатлон',
#   'баре',
#   'смотрели',
#   'общем',
#   'шикарное',
#   'место',
#   'показывают',
#   'душе',
#   'угодно'],
#  ['жизни', 'б', 'твиттер', 'жесткая', 'проекция', 'жизни'],
#  ['папа', 'комнаты', 'чаще'],
#  ['таким',
#   'любили',
#   'таких',
#   'прекрасных',
#   'людей',
#   'увы',
#   'мало',
#   'безумно',
#   'счастлива',
#   'общаюсь',
#   'тобой'],
#  ['голодный', 'день'],
#  ['это',
#   'ест',
#   'ест',
#   'просто',
#   'тайне',
#   'ибо',
#   'наглый',
#   'хачет',
#   'кем',
#   'делиться'],
#  ['лежу', 'реально', 'сил', 'делать'],
#  ['оказывается', 'парням', 'нужно', 'эх', 'тому', 'стремилась', 'менять'],
#  ['девчееенки',
#   'реально',
#   'хочу',
#   'просыпаться',
#   'именно',
#   'щетина',
#   'касается',
#   'моей',
#   'щеки',
#   'тихо',
#   'нашептывает',
#   'мышонок',
#   'просыпайся'],
#  ['говоришь',
#   'жуйк',
#   'очередной',
#   'аськокапец',
#   'правда',
#   'похоже',
#   'капец',
#   'копчик',
#   'вместо',
#   'обычных',
#   'онлайн'],
#  ['болят', 'колени', 'синяк', 'ничего', 'сегодня', 'насобираю'],
#  ['артем',
#   'артем',
#   'ай',
#   'ай',
#   'яй',
#   'скинул',
#   'очередную',
#   'партию',
#   'фоток'],
#  ['урааааааа', 'божечки', 'просто', 'уписаюсь', 'радости', 'сдалаааа'],
#  ['оченььь',
#   'рада',
#   'нашей',
#   'встрече',
#   'всё',
#   'странно',
#   'круто',
#   'спасибо',
#   'тебе',
#   'вечер'],
#  ['apocalyptica', 'feat', 'воровайки', 'hope', 'мусорок', 'шей', 'срок'],
#  ['брат',
#   'дай',
#   'пять',
#   'ток',
#   'класса',
#   'ахах',
#   'ксюхе',
#   'кстати',
#   'понравился',
#   'd'],
#  ['веселуха', 'нашелся', 'одногрупнник', 'месяц', 'пропадал'],
#  ['хах', 'девки', 'рассмешили', 'смотрели', 'долго', 'пока', 'ушел'],
#  ['те', 'работают', 'представлении', 'такие', 'мысли', 'согласен'],
#  ['кинофестиваль',
#   'фильм',
#   'собственным',
#   'участием',
#   'видел',
#   'самому',
#   'интересно',
#   'зайдет'],
#  ['вообще', 'пацаном', 'родиться', 'проблем', 'меньше'],
#  ['думаю', 'это', 'хотя', 'возможно'],
#  ['надеюсь', 'всё', 'наладится'],
#  ['всем',
#   'прекрасного',
#   'вкусного',
#   'утра',
#   'пускай',
#   'сегодня',
#   'ваше',
#   'настроение',
#   'никто',
#   'сможет',
#   'испортить'],
#  ['пхаахаахахахахаха', 'подавился', 'сука', 'dddddddd'],
#  ['нужно', 'определенно', 'двоих', 'оргия'],
#  ['ja', 'rule', 'гей', 'больше', 'нечего', 'искать'],
#  ['каком', 'чуде', 'говорила', 'ахахаха'],
#  ['соскучился', 'придумаю', 'вами', 'сделать'],
#  ['орешек', 'нам', 'попался', 'знак', 'судьбы', 'прям', 'любовь', 'повсюду'],
#  ['поздравояю',
#   'началом',
#   'новой',
#   'рабочей',
#   'недели',
#   'некоторых',
#   'началом',
#   'отпуска'],
#  ['души', 'ржем', 'настей', 'моей', 'глупостью', 'd'],
#  ['понял', 'это', 'часов', 'спал'],
#  ['спасибо',
#   'чувак',
#   'обязательно',
#   'передам',
#   'короче',
#   'папой',
#   'сложились',
#   'деньгами',
#   'золота',
#   'подарим'],
#  ['слышу',
#   'творческие',
#   'горячие',
#   'споры',
#   'моих',
#   'соседей',
#   'дедушки',
#   'бабушки',
#   'радуюсь',
#   'красиво',
#   'эмоционально',
#   'ругаются'],
#  ['ждет', 'семью', 'гобозовых', 'ваши', 'прогнозы', 'будущее'],
#  ['сегодня',
#   'третьей',
#   'ко',
#   'второй',
#   'хотя',
#   'охота',
#   'ехать',
#   'универ',
#   'd'],
#  ['знал', 'доме', 'никогда', 'чист', 'бывает'],
#  ['бессноная', 'ночь', 'лучше', 'зачетом'],
#  ['получил', 'плеер', 'управляемый', 'телефоном'],
#  ['хаха', 'даа', 'это', 'можешь'],
#  ['просто', 'фантазия', 'бушует', 'знать'],
#  ['наверно',
#   'чёртова',
#   'весна',
#   'каждый',
#   'год',
#   'жизнь',
#   'подсовывает',
#   'али'],
#  ['аккаунт', 'настроение', 'создавался', 'злая', 'мужики', 'всё'],
#  ['сразу', 'весь', 'твитор'],
#  ['нашёл', 'бро', 'yanahale', 'серьезно', 'd'],
#  ['новый',
#   'проект',
#   'открыл',
#   'например',
#   'вино',
#   'всякое',
#   'такое',
#   'макс',
#   'pls',
#   'прочее'],
#  ['каждое',
#   'утро',
#   'космический',
#   'броша',
#   'сети',
#   'наверное',
#   'воюет',
#   'холодильником'],
#  ['пописдовал', 'прием', 'врачу', 'желаю', 'удачи', 'сегодня'],
#  ['помню',
#   'левашов',
#   'заебывал',
#   'рт',
#   'ленту',
#   'лимитов',
#   'нахуй',
#   'арали',
#   'd',
#   'хватает',
#   'помимо',
#   'упртст'],
#  ['др', 'светлого', 'наилучшего', 'болей'],
#  ['легла',
#   'спать',
#   'вчера',
#   'проснулась',
#   'сегодня',
#   'утра',
#   'мама',
#   'призналась',
#   'момент',
#   'подумала',
#   'умерла',
#   'всё',
#   'клубнично'],
#  [],
#  ['завалы',
#   'вузе',
#   'разгребать',
#   'успеваю',
#   'скорей',
#   'выходные',
#   'скорей',
#   'новый',
#   'год',
#   'отдохну'],
#  ['новый', 'год', 'летом'],
#  ['stable', 'стремно', 'продакшен', 'ставить'],
#  ['очень', 'веселый', 'насыщенный', 'день', 'проведен', 'моим', 'пупсиком'],
#  ['жубо',
#   'работает',
#   'смотри',
#   'подписку',
#   'возможно',
#   'жубо',
#   'сервере',
#   'твой',
#   'жид',
#   'глюк'],
#  ['поэтому', 'сьебалась', 'геометрии', 'пизда', 'завтра'],
#  ['саазала', 'поставит', 'проглядела', 'блять'],
#  ['держусь', 'месте'],
#  ['плохо',
#   'стало',
#   'легла',
#   'отдыхать',
#   'стук',
#   'окно',
#   'проснулась',
#   'смотрю',
#   'голубь',
#   'белый',
#   'стучится',
#   'клювом',
#   'глядит',
#   'аж',
#   'настроение',
#   'поднялось',
#   'з'],
#  ['шучу', 'шучу', 'взрывать'],
#  ['буду', 'фотографироваться', 'тех', 'пор', 'пока', 'понравится', 'd'],
#  ['афроамериканцы', 'моей', 'практике', 'впервые'],
#  ['отстанем', 'окей'],
#  ['rovio',
#   'запускают',
#   'angry',
#   'birds',
#   'go',
#   'день',
#   'gta',
#   'sa',
#   'удачи',
#   'горячим',
#   'финским',
#   'парням'],
#  ['капец',
#   'потерях',
#   'знаю',
#   'думать',
#   'реагировать',
#   'хорошо',
#   'инна',
#   'рядом'],
#  ['неть', 'ле', 'итак', 'дальше', 'пройдете'],
#  ...]

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
#model = KeyedVectors.load_word2vec_format('ruscorpora_upos_skipgram_300_5_2018.vec', binary=False)
my_model = Word2Vec(model_train, window=5, min_count=0, size=100, workers=4)

# %%
my_model

# %%
vectors = []
p=0
for i in new_tweets:
    vec = []
    for k in i:
        try:
            model = my_model.wv[k]
            vec.append(model)
        except:
            #vec.append('no model')
            p+=1
    vectors.append(vec)
print(len(vectors))
print('Words missing: ', p)
# Out:
# 10000
# Words missing:  4690

# %%
sum_vec = []
for i in vectors:
    #print(i)
    sum_vec.append(np.sum(i, axis=0)/len(i))
print(len(sum_vec))
# Out:
# C:\programs\anaconda\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.
# 10000

# %%
len(tweets)
# Out:
# 10000

# %%
from sklearn import preprocessing

scaler = preprocessing.StandardScaler()
for col in ['retw', 'count', 'foll', 'friend', 'list', 'people', 'tags', 'emoji_bad', 'emoji_good', 'three_dots']:
    x = tweets[col].values.reshape(-1, 1)
    print(col, len(x))
    standardized = scaler.fit_transform(x)
    tweets[col] = standardized
# Out:
# retw 10000
# count 10000
# foll 10000
# friend 10000
# list 10000
# people 10000
# tags 10000
# emoji_bad 10000
# emoji_good 10000
# three_dots 10000
# C:\programs\anaconda\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# Колонки *id* и *namе* не несут никакой важной информации в связи с тем, что подавляющее большинство элементов в них является уникальным, формат колонки *date* нераспознаваем, поэтому ей сложно воспользоваться для обучения модели

# %%
try:
    tweets.drop('id', axis=1, inplace=True)
    tweets.drop('date', axis=1, inplace=True)
    tweets.drop('name', axis=1, inplace=True)
except:
    pass

# %%
f = ['f'+str(i) for i,l in enumerate(sum_vec[0])]

for i in f:
    tweets[i] = ""

# %%
for a,b in enumerate(sum_vec):
    sum_vec[a] = b.tolist()
print(len(sum_vec))
len(sum_vec[0])
# Out:
# 10000
# 100

# %%
#vecs = sum_vec
#tweets_new = tweets.drop('text', axis=1)

for el, vecs in enumerate(sum_vec):
    if el%100 == 0:
        print('done vec #' + str(el))
    tweets.at[el, 'f0':'f99'] = vecs
    #for n, k in enumerate(f):
     #   tweets[k][el] = vecs[n]
      #  print(n)
tweets

#for string in range(len(tweets)):
 #   tweets.loc[string][f[0]:f[-1]] = sum_vec[string]
  #  break
#tweets
# Out:
# done vec #0
# done vec #100
# done vec #200
# done vec #300
# done vec #400
# done vec #500
# done vec #600
# done vec #700
# done vec #800
# done vec #900
# done vec #1000
# done vec #1100
# done vec #1200
# done vec #1300
# done vec #1400
# done vec #1500
# done vec #1600
# done vec #1700
# done vec #1800
# done vec #1900
# done vec #2000
# done vec #2100
# done vec #2200
# done vec #2300
# done vec #2400
# done vec #2500
# done vec #2600
# done vec #2700
# done vec #2800
# done vec #2900
# done vec #3000
# done vec #3100
# done vec #3200
# done vec #3300
# done vec #3400
# done vec #3500
# done vec #3600
# done vec #3700
# done vec #3800
# done vec #3900
# done vec #4000
# done vec #4100
# done vec #4200
# done vec #4300
# done vec #4400
# done vec #4500
# done vec #4600
# done vec #4700
# done vec #4800
# done vec #4900
# done vec #5000
# done vec #5100
# done vec #5200
# done vec #5300
# done vec #5400
# done vec #5500
# done vec #5600
# done vec #5700
# done vec #5800
# done vec #5900
# done vec #6000
# done vec #6100
# done vec #6200
# done vec #6300
# done vec #6400
# done vec #6500
# done vec #6600
# done vec #6700
# done vec #6800
# done vec #6900
# done vec #7000
# done vec #7100
# done vec #7200
# done vec #7300
# done vec #7400
# done vec #7500
# done vec #7600
# done vec #7700
# done vec #7800
# done vec #7900
# done vec #8000
# done vec #8100
# done vec #8200
# done vec #8300
# done vec #8400
# done vec #8500
# done vec #8600
# done vec #8700
# done vec #8800
# done vec #8900
# done vec #9000
# done vec #9100
# done vec #9200
# done vec #9300
# done vec #9400
# done vec #9500
# done vec #9600
# done vec #9700
# done vec #9800
# done vec #9900
#                                                    text  class  rep      retw  \
# 0          @LadySelutina нууу, а вот мне не с кем пока(     -1    0 -0.070989
# 1     У тебя хорошо получается лгать? — к сожалению ...     -1    0 -0.070989
# 2     RT @Limonih: @MarinaP_LOVE1D пасибо:)\r\nя вро...      1    0 -0.039628
# 3     выучить все параграфы по физике за ночь, надею...      1    0 -0.070989
# 9982  Конец света? Да, слышал! На улице шедевральное...     -1    0 -0.070989
# 9983  Налегла на Кэти и Тейлор в последнее время. Во...      1    0 -0.070989
# 9984  RT @ikat_b: @meow_Kiljjoy меня не пустят с: я ...      1    0 -0.039628
# 9985  Дневной квест "От Затулинки до Учительской при...      1    0 -0.070989
# 9986  ФОНАРИ НА ЛЮБОЙ ВКУС И ЦВЕТ)) / http://t.co/bN...      1    0 -0.070989
# 9987  RT @VeraMedvedkina: @alincakalashnic потеряешь...      1    0  0.023094
# 9988  @korolewa1998 заболела, с мамой чуть не поссор...     -1    0 -0.070989
# 9989  @yanis_popov Дента самые нормальные согласилис...      1    0 -0.070989
# 9990       Бл по понедельникам две пары физики подряд((     -1    0 -0.070989
# 9991  @SugarbatGalsan Хэлээд юугхэв хө :) @enkhboldz...      1    0 -0.070989
# 9992  Photo: Несколько кадров на память) как народ у...      1    0 -0.070989
# 9993  @elk_art_w, сегодня вопросов по поводу смс-при...      1    0 -0.070989
# 9994  Вот служба безопасности @evernote_ru молодцы! ...      1    0 -0.070989
# 9995  Сейчас сижу пью чай с конфетками, и у меня поч...     -1    0 -0.070989
# 9996  #новости 10 лет курил, 4 дня уже не курю))) бе...      1    0 -0.070989
# 9997  @yasno_ok "Затем данные двух исследований были...     -1    0 -0.070989
# 9998  @ohrimekokatya остались,конечно, люди не в них...      1    0 -0.070989
# 9999  @Nillie_s aaaa!!! Ды ты чтоо?? Классно! Я еще ...      1    0 -0.070989
#
#       fav     count      foll     friend      list    people     ...       \
# 0       0 -0.387304 -0.089385  -0.198514 -0.110708  0.348068     ...
# 1       0 -0.402316 -0.105820   0.056421 -0.110708 -0.784597     ...
# 2       0  0.329998  0.164567   0.704110 -0.062014  1.480732     ...
# 3       0 -0.324655 -0.108295  -0.206279 -0.110708 -0.784597     ...
# 4       0 -0.396693 -0.110062  -0.213396 -0.110708 -0.784597     ...
# 5       0 -0.387887 -0.068532  -0.047106 -0.110708 -0.784597     ...
# 6       0  0.671726 -0.092743  -0.191397 -0.110708  1.480732     ...
# 7       0 -0.319616  0.094938   0.324943 -0.110708  0.348068     ...
# 8       0  0.077759  0.271308   0.951281 -0.062014  0.348068     ...
# 9       0 -0.397170 -0.111652  -0.207573 -0.110708 -0.784597     ...
# 10      0 -0.375739 -0.107234  -0.186868 -0.098534 -0.784597     ...
# 11      0 -0.249435 -0.106174  -0.197220 -0.110708 -0.784597     ...
# 12      0 -0.396215 -0.108825  -0.209514 -0.110708 -0.784597     ...
# 13      0  1.402872  0.280675   0.197476  0.108417  0.348068     ...
# 14      0 -0.357650 -0.108471  -0.207573 -0.098534 -0.784597     ...
# 15      0 -0.373830 -0.076838  -0.100811 -0.110708  0.348068     ...
# 16      0 -0.393934 -0.109532  -0.208867 -0.110708  0.348068     ...
# 17      0 -0.377437 -0.111122  -0.216632 -0.110708 -0.784597     ...
# 18      0  0.580273 -0.041139  -0.109869  0.035375  0.348068     ...
# 19      0 -0.299193 -0.056691  -0.032224 -0.001146 -0.784597     ...
# ...           ...         ...         ...          ...
# 9970    -0.154549    0.201565      0.1529   -0.0168819
# 9971    -0.107478    0.316418    0.214854   -0.0673273
# 9972     -0.39221    0.261645    0.430789    -0.137434
# 9973    -0.332348    0.344299    0.283158    -0.225715
# 9974    -0.282566    0.575078    0.217962   0.00857294
# 9975    -0.201244    0.260301   0.0524851    0.0507143
# 9976    -0.450048    0.596751    0.172073     0.130617
# 9977    -0.796236    0.698732    0.814763    -0.243111
# 9978    -0.169637    0.269731    0.255237     -0.15169
# 9979    -0.418574     0.86753    0.570299   -0.0750603
# 9980    -0.600588    0.795361    0.141119     0.212223
# 9981    -0.512011    0.778131     0.17418     0.165279
# 9982    -0.172814    0.395438   0.0786951     0.143731
# 9983    -0.213074    0.537485    0.213347    0.0400802
# 9984    -0.259148    0.419649   0.0599894     0.135456
# 9985    -0.272634    0.337394   0.0831566     0.162023
# 9986    -0.132416    0.340373    0.319914   -0.0897161
# 9987  -0.00187921  0.00244216  0.00510651   0.00179909
# 9988    -0.325851    0.793789    0.354906   -0.0318589
# 9989    -0.084553    0.138128    0.228896    -0.205046
# 9990      -0.4762    0.526732    0.013439      0.27235
# 9991  0.000952668   0.0153093  0.00656651 -0.000614636
# 9992    -0.346031    0.465735    0.122697     0.125973
# 9993    -0.314159    0.577376    0.241845    0.0410585
# 9994     -0.09312    0.307536    0.288257   -0.0887053
# 9995    -0.526362     1.30509   0.0762279     0.290312
# 9996    -0.500903    0.378561    0.142037     0.263227
# 9997    -0.235868    0.313077    0.156135    0.0537165
# 9998    -0.747619    0.555886    0.480979   -0.0582175
# 9999     -0.19214    0.544057    0.362548   -0.0819057
#
# [10000 rows x 114 columns]

# %%
tweets.drop('text', axis=1, inplace=True)
tweets.to_csv('tweets_coords.csv', sep=';', encoding='utf-8')

# %%
t = pd.read_csv('tweets_coords.csv', sep=';')

# %%
t.drop('Unnamed: 0', axis=1, inplace=True)

# %%
y = t['class'].values
X = t.drop('class', axis=1)

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(strategy='most_frequent', axis=0)

X[:] = imputer.fit_transform(X)

# %%
from sklearn import preprocessing

scaler = preprocessing.StandardScaler()

for col in ['f'+str(i) for i in range (0,100)]:
    x = X[col].values.reshape(-1, 1)
    standardized = scaler.fit_transform(x)
    X[col] = standardized

# %%
X
# Out:
#       rep      retw  fav     count      foll     friend      list    people  \
# 0     0.0 -0.070989  0.0 -0.387304 -0.089385  -0.198514 -0.110708  0.348068
# 1     0.0 -0.070989  0.0 -0.402316 -0.105820   0.056421 -0.110708 -0.784597
# 2     0.0 -0.039628  0.0  0.329998  0.164567   0.704110 -0.062014  1.480732
# 3     0.0 -0.070989  0.0 -0.324655 -0.108295  -0.206279 -0.110708 -0.784597
# 4     0.0 -0.070989  0.0 -0.396693 -0.110062  -0.213396 -0.110708 -0.784597
# 5     0.0 -0.070989  0.0 -0.387887 -0.068532  -0.047106 -0.110708 -0.784597
# 6     0.0 -0.070989  0.0  0.671726 -0.092743  -0.191397 -0.110708  1.480732
# 7     0.0 -0.070989  0.0 -0.319616  0.094938   0.324943 -0.110708  0.348068
# 8     0.0  0.023094  0.0  0.077759  0.271308   0.951281 -0.062014  0.348068
# 9972  0.534954 -0.426099 -0.333032 -0.903688  0.562464 -0.545090
# 9973 -0.389747  0.318426 -0.058041 -0.650922 -0.024603 -0.984618
# 9974 -0.376742  0.761052  0.170643  0.054832 -0.283861  0.181844
# 9975 -1.096022  1.014602  0.544213 -0.907800 -0.941896  0.391657
# 9976 -0.111214 -0.157458 -0.598726  0.121111 -0.466344  0.789471
# 9977  2.323229 -1.177966 -2.189021  0.432985  2.089374 -1.071231
# 9978 -0.513388 -0.099691  0.689408 -0.878960 -0.135635 -0.616065
# 9979  1.155706 -0.697251 -0.454142  0.949192  1.117240 -0.234546
# 9980 -0.056242 -0.484271 -1.290264  0.728488 -0.589433  1.195769
# 9981  0.380353 -1.302312 -0.883364  0.675796 -0.457966  0.962047
# 9982 -0.680352  0.840103  0.674813 -0.494530 -0.837670  0.854762
# 9983 -0.297491 -0.231299  0.489870 -0.060132 -0.302214  0.338711
# 9984 -1.100007  0.900171  0.278219 -0.420491 -0.912055  0.813563
# 9985 -1.147831  1.247033  0.216266 -0.672038 -0.819928  0.945834
# 9986 -0.206758  0.284153  0.860392 -0.662927  0.121562 -0.307513
# 9987 -2.220075  1.748517  1.460042 -1.696366 -1.130301  0.148119
# 9988  0.477231 -0.896651 -0.028195  0.723682  0.260709 -0.019456
# 9989 -0.766013 -0.117413  1.080261 -1.281419 -0.240382 -0.881713
# 9990  0.043737  0.568049 -0.718860 -0.093015 -1.097167  1.495127
# 9991 -2.116271  1.697706  1.473051 -1.657017 -1.124496  0.136102
# 9992 -0.015696  0.223564 -0.120898 -0.279552 -0.662693  0.766353
# 9993  0.005557  0.282940  0.025511  0.061860 -0.188887  0.343583
# 9994 -0.616451  0.477279  1.040906 -0.763349 -0.004327 -0.302481
# 9995  1.077402 -0.937849 -0.949290  2.287301 -0.847481  1.584555
# 9996 -0.071024  0.977959 -0.832337 -0.546142 -0.585785  1.449707
# 9997 -0.735450  0.951151  0.385162 -0.746402 -0.529722  0.406604
# 9998  0.980873 -2.070855 -1.965687 -0.003860  0.762049 -0.150689
# 9999 -0.526446  0.166929  0.586037 -0.040035  0.291097 -0.268627
#
# [10000 rows x 112 columns]

# %%
print("Null values: {0}".format(X.isnull().values.any()))
print("Count of NaN values: {0}".format(np.sum(X.isnull().values)))
# Out:
# Null values: False
# Count of NaN values: 0

# %%
#from sklearn import svm


#model_svm = svm.SVC(kernel='linear', C=10, gamma='auto', class_weight='balanced') 
#model_svm.fit(X, y)
#model_svm.score(X, y)
#predicted = model_svm.predict(X)

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV
if type(X) != np.ndarray:
    X = X.values
if type(y) != np.ndarray:
    y = y.values
parameters = {'kernel':('linear',),'C':[1, 10], 'class_weight':('balanced',)}
svc = svm.SVC()
clf = GridSearchCV(svc, parameters)

# %%
clf.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-154-a74ad04ea648> in <module>()
# ----> 1 clf.best_estimator_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'

# %%
scoring = ['accuracy', 'precision', 'recall', 'f1']
from sklearn.model_selection import cross_validate
cross_validate(clf, X, y, scoring=scoring, cv=5)
# Out:
# C:\programs\anaconda\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('train_accuracy'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\programs\anaconda\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('train_f1'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\programs\anaconda\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('train_precision'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\programs\anaconda\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('train_recall'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# {'fit_time': array([20.94124675, 21.7239387 , 17.21236753, 21.94908094, 18.8289597 ]),
#  'score_time': array([0.34081435, 0.46800947, 0.3240037 , 0.3360076 , 0.37200618]),
#  'test_accuracy': array([0.987 , 0.99  , 0.9865, 0.9865, 0.9855]),
#  'test_f1': array([0.99073414, 0.99283154, 0.99036059, 0.99038119, 0.98972724]),
#  'test_precision': array([0.9886202 , 0.99640288, 0.99000714, 0.98791756, 0.98172874]),
#  'test_recall': array([0.99285714, 0.98928571, 0.99071429, 0.99285714, 0.99785714]),
#  'train_accuracy': array([0.991625, 0.988875, 0.98975 , 0.9915  , 0.9905  ]),
#  'train_f1': array([0.99403437, 0.99204291, 0.99266547, 0.99393507, 0.99325643]),
#  'train_precision': array([0.99129817, 0.99337511, 0.99444444, 0.99287242, 0.98712522]),
#  'train_recall': array([0.99678571, 0.99071429, 0.99089286, 0.995     , 0.99946429])}

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=5, shuffle=True) 
#X = X.values

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

accuracy = []
precision = []
recall = []
f1 = []

iteration_index = 0
model_svm = clf.best_estimator_
target_names = ['neg', 'pos']

for train_indexes, test_indexes in kf.split(X,y):
    iteration_index+=1
    X_train = X[train_indexes]
    y_train = y[train_indexes]
    
    X_test = X[test_indexes]
    y_test = y[test_indexes]
    
    model_svm.fit(X_train, y_train)
    model_svm.score(X_train, y_train)
    predicted = model_svm.predict(X_test)
    
    current_acc = accuracy_score(y_test, predicted)
    current_prec = precision_score(y_test, predicted)
    current_rec = recall_score(y_test, predicted)
    current_f1 = f1_score(y_test, predicted)
    #print("Iteration #{0}: Accuracy : {1}, Precision : {2}, Recall : {3}, F1 : {4}".format(iteration_index, current_acc, current_prec, current_rec, current_f1))
    
    print("Iteration #{0}: \n".format(iteration_index), classification_report(y_test, predicted, target_names=target_names))
    
    accuracy.append(current_acc)
    precision.append(current_prec)
    recall.append(current_rec)
    f1.append(current_f1)

print("\nOverall: ")
print("\tAccuracy : {0}".format(np.mean(accuracy)))
print("\tPrecision : {0}".format(np.mean(precision)))
print("\tRecall : {0}".format(np.mean(recall)))
print("\tF1 : {0}".format(np.mean(f1)))
# Out:
# Iteration #1:
#               precision    recall  f1-score   support
#
#         neg       1.00      0.96      0.98       634
#         pos       0.98      1.00      0.99      1366
#
# avg / total       0.99      0.99      0.99      2000
#
# Iteration #2:
#               precision    recall  f1-score   support
#
#         neg       0.99      0.96      0.97       572
#         pos       0.98      0.99      0.99      1428
#
# avg / total       0.99      0.98      0.98      2000
#
# Iteration #3:
#               precision    recall  f1-score   support
#
#         neg       0.98      0.97      0.97       572
#         pos       0.99      0.99      0.99      1428
#
# avg / total       0.98      0.98      0.98      2000
#
# Iteration #4:
#               precision    recall  f1-score   support
#
#         neg       0.97      0.99      0.98       622
#         pos       0.99      0.99      0.99      1378
#
# avg / total       0.99      0.99      0.99      2000
#
# Iteration #5:
#               precision    recall  f1-score   support
#
#         neg       0.98      0.99      0.99       600
#         pos       1.00      0.99      0.99      1400
#
# avg / total       0.99      0.99      0.99      2000
#
#
# Overall:
# 	Accuracy : 0.9866999999999999
# 	Precision : 0.9890893416851145
# 	Recall : 0.9920060972838625
# 	F1 : 0.9905215294867059

# %%
from sklearn.neighbors import KNeighborsClassifier
#neigh = KNeighborsClassifier(n_neighbors=5)

parameters = {'n_neighbors':[1, 10]}
knn = KNeighborsClassifier()
clf_knn = GridSearchCV(knn, parameters)
clf_knn.fit(X, y)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform'),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_neighbors': [1, 10]}, pre_dispatch='2*n_jobs',
#        refit=True, return_train_score='warn', scoring=None, verbose=0)

# %%
accuracy = []
precision = []
recall = []
f1 = []

iteration_index = 0
neigh = clf_knn.best_estimator_
target_names = ['neg', 'pos']

for train_indexes, test_indexes in kf.split(X,y):
    iteration_index+=1
    X_train = X[train_indexes]
    y_train = y[train_indexes]
    
    X_test = X[test_indexes]
    y_test = y[test_indexes]
    
    neigh.fit(X_train, y_train) 
    predicted = neigh.predict(X_test)
    
    current_acc = accuracy_score(y_test, predicted)
    current_prec = precision_score(y_test, predicted)
    current_rec = recall_score(y_test, predicted)
    current_f1 = f1_score(y_test, predicted)
    #print("Iteration #{0}: Accuracy : {1}, Precision : {2}, Recall : {3}, F1 : {4}".format(iteration_index, current_acc, current_prec, current_rec, current_f1))
    print("Iteration #{0}: \n".format(iteration_index), classification_report(y_test, predicted, target_names=target_names))

    
    accuracy.append(current_acc)
    precision.append(current_prec)
    recall.append(current_rec)
    f1.append(current_f1)

print("\nOverall: ")
print("\tAccuracy : {0}".format(np.mean(accuracy)))
print("\tPrecision : {0}".format(np.mean(precision)))
print("\tRecall : {0}".format(np.mean(recall)))
print("\tF1 : {0}".format(np.mean(f1)))
# Out:
# Iteration #1:
#               precision    recall  f1-score   support
#
#         neg       0.90      0.78      0.84       573
#         pos       0.92      0.96      0.94      1427
#
# avg / total       0.91      0.91      0.91      2000
#
# Iteration #2:
#               precision    recall  f1-score   support
#
#         neg       0.94      0.77      0.85       601
#         pos       0.91      0.98      0.94      1399
#
# avg / total       0.92      0.92      0.91      2000
#
# Iteration #3:
#               precision    recall  f1-score   support
#
#         neg       0.95      0.77      0.85       584
#         pos       0.91      0.98      0.95      1416
#
# avg / total       0.92      0.92      0.92      2000
#
# Iteration #4:
#               precision    recall  f1-score   support
#
#         neg       0.90      0.76      0.82       607
#         pos       0.90      0.96      0.93      1393
#
# avg / total       0.90      0.90      0.90      2000
#
# Iteration #5:
#               precision    recall  f1-score   support
#
#         neg       0.93      0.78      0.85       635
#         pos       0.90      0.97      0.94      1365
#
# avg / total       0.91      0.91      0.91      2000
#
#
# Overall:
# 	Accuracy : 0.9121
# 	Precision : 0.9087254195463341
# 	Recall : 0.9719981466984677
# 	F1 : 0.9392817836753391

# %% [markdown]
# Точность работы алгоритма получилась достаточно высокой, что удивительно (при использовании grid_search точность стала еще выше).
# Это может быть связано с:
# 1. из-за недостоанчной мощности компьютера для ускорения обработки текста выборку пришлось сократить до 10000
# 2. модель w2v обучалась непосредственно на выборке, поэтому многие достаточно уникальные для выбрки слова и символы были достаточно точно выделены (к тому же обучение было без лемматизации в связи с недостоаточной мозностью компьютера).
# 3. также были добавлены и другие признаки для каждого экземпляра выборки, что, возможно, позволило более точно описать каждый экземпляр
